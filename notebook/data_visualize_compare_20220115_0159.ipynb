# %% [markdown]
# # Exploitation Comparison of Different Zero-sum Game Methods
# The figures show the learning curve of the exploiter after the model is trained with different type of methods. The exploiter is set as the second player for all envs and methods.

# %%
import json

def load_data(file_name):
    file_dir = folder+files[0]
    file_dir = folder+file_name
    # print(file_dir)
    
    data = json.load( open(file_dir+"/process.json"))
    # print(data.keys())
    return data

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['savefig.facecolor']='white'
# plt.style.use('seaborn-whitegrid')
plt.style.use('default')
import matplotlib.cm as cm


def plot(data, method, color, agent_to_plot, smooth_radius=200, range=100000):
    def smooth(y, radius=200, mode='two_sided'):
        if len(y) < 2*radius+1:
            return np.ones_like(y) * y.mean()
        elif mode == 'two_sided':
            convkernel = np.ones(2 * radius+1)
            return np.convolve(y, convkernel, mode='same') / \
                   np.convolve(np.ones_like(y), convkernel, mode='same')
        elif mode == 'causal':
            convkernel = np.ones(radius)
            out = np.convolve(y, convkernel,mode='full') / \
                  np.convolve(np.ones_like(y), convkernel, mode='full')
            return out[:-radius+1]

    k = method
    v = data[agent_to_plot]
    try:
        plt.plot(v[:range], color=color, alpha=0.2)
        plt.plot(smooth(v[:range], radius=smooth_radius), color=color, label=k)
    except:
        pass

    
img_path = 'generated_img/'

# %%
env = 'boxing'
folder = '../data/log/20220119_0521_exploit/'
files = ! ls $folder
print(files)
colors = cm.rainbow(np.linspace(0, 1, 7))
# colors = ['r', 'b', 'c', 'orange', 'g', 'grey']
agent_to_plot = 'second_0'  # 'first_0' or 'second_0'
env_files =[f for f in files if env in f]
print(env_files)

for f, c in zip(env_files, colors):
    data = load_data(f)
    method = f.split('v1_')[-1]
    plot(data['episode_reward'], method, c, agent_to_plot, smooth_radius=20)

plt.legend()
plt.grid()
plt.title(f'Exploitation Test-{env}')
plt.xlabel('Episode')
plt.ylabel('Exploiter Reward')
# savepath=f'generated_img/compare_exploitation_{env}.pdf'
# plt.savefig(savepath, bbox_inches='tight',)
# Out:
# ['pettingzoo_boxing_v1_fictitious_selfplay2', 'pettingzoo_boxing_v1_nash_dqn', 'pettingzoo_boxing_v1_nash_dqn_exploiter', 'pettingzoo_boxing_v1_nash_ppo', 'pettingzoo_boxing_v1_nfsp', 'pettingzoo_boxing_v1_nxdo2', 'pettingzoo_boxing_v1_selfplay2', 'pettingzoo_pong_v2_fictitious_selfplay2', 'pettingzoo_pong_v2_nash_dqn', 'pettingzoo_pong_v2_nash_dqn_exploiter', 'pettingzoo_pong_v2_nash_ppo', 'pettingzoo_pong_v2_nfsp', 'pettingzoo_pong_v2_nxdo2', 'pettingzoo_pong_v2_selfplay2', 'pettingzoo_surround_v1_fictitious_selfplay2', 'pettingzoo_surround_v1_nash_dqn', 'pettingzoo_surround_v1_nash_dqn_exploiter', 'pettingzoo_surround_v1_nash_ppo', 'pettingzoo_surround_v1_nfsp', 'pettingzoo_surround_v1_nxdo2', 'pettingzoo_surround_v1_selfplay2', 'pettingzoo_tennis_v2_fictitious_selfplay2', 'pettingzoo_tennis_v2_nash_dqn', 'pettingzoo_tennis_v2_nash_dqn_exploiter', 'pettingzoo_tennis_v2_nash_ppo', 'pettingzoo_tennis_v2_nfsp', 'pettingzoo_tennis_v2_nxdo2', 'pettingzoo_tennis_v2_selfplay2', 'slimevolley_SlimeVolley-v0_fictitious_selfplay2', 'slimevolley_SlimeVolley-v0_nash_dqn', 'slimevolley_SlimeVolley-v0_nash_dqn_exploiter', 'slimevolley_SlimeVolley-v0_nash_ppo', 'slimevolley_SlimeVolley-v0_nfsp', 'slimevolley_SlimeVolley-v0_nxdo2', 'slimevolley_SlimeVolley-v0_selfplay2']
# ['pettingzoo_boxing_v1_fictitious_selfplay2', 'pettingzoo_boxing_v1_nash_dqn', 'pettingzoo_boxing_v1_nash_dqn_exploiter', 'pettingzoo_boxing_v1_nash_ppo', 'pettingzoo_boxing_v1_nfsp', 'pettingzoo_boxing_v1_nxdo2', 'pettingzoo_boxing_v1_selfplay2']
# ../data/log/20220119_0521_exploit/pettingzoo_boxing_v1_fictitious_selfplay2
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220119_0521_exploit/pettingzoo_boxing_v1_nash_dqn
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220119_0521_exploit/pettingzoo_boxing_v1_nash_dqn_exploiter
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220119_0521_exploit/pettingzoo_boxing_v1_nash_ppo
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220119_0521_exploit/pettingzoo_boxing_v1_nfsp
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220119_0521_exploit/pettingzoo_boxing_v1_nxdo2
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220119_0521_exploit/pettingzoo_boxing_v1_selfplay2
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# Text(0, 0.5, 'Exploiter Reward')

# %%
import os

envs = ['slimevolley', 'boxing', 'pong', 'surround', 'tennis']
model_idxs = ['20220119_0521', '20220119_0524', '20220119_0526']
data_folder = '../data'

for env in envs:
    for idx  in model_idxs:    
        folder = f'{data_folder}/log/{idx}_exploit/'
        files = ! ls $folder
        # print(files)
        colors = cm.rainbow(np.linspace(0, 1, 7))
        # colors = ['r', 'b', 'c', 'orange', 'g', 'grey']
        agent_to_plot = 'second_0'  # 'first_0' or 'second_0'
        env_files =[f for f in files if env in f]
        # print(env_files)

        fig= plt.figure(figsize=(8, 5), dpi=300)
        for f, c in zip(env_files, colors):
            try:
                data = load_data(f)
            except:
                print(f"{f} not loaded!")
                break
            method = f.split('v1_')[-1]
            plot(data['episode_reward'], method, c, agent_to_plot, smooth_radius=20)

        plt.legend()
        plt.grid()
        plt.title(f'Exploitation Test-{env}')
        plt.xlabel('Episode')
        plt.ylabel('Exploiter Reward')
        savepath = f'{data_folder}/figs/exploitation_result/'
        os.makedirs(savepath, exist_ok=True)
        savefile = savepath+f'exploit_{idx}_{env}.png'
        plt.savefig(savefile, bbox_inches='tight', )
        # plt.show()
        plt.close()
# Out:
# No handles with labels found to put in legend.
# pettingzoo_pong_v2_fictitious_selfplay2 not loaded!
# pettingzoo_surround_v1_nash_dqn not loaded!
# pettingzoo_surround_v1_nash_dqn_exploiter not loaded!

# %%
import os

envs = ['double_dunk']
model_idxs = ['20220119_1543', '20220119_1545', '20220119_1551']
data_folder = '../data'

for env in envs:
    for idx  in model_idxs:    
        folder = f'{data_folder}/log/{idx}_exploit/'
        files = ! ls $folder
        colors = cm.rainbow(np.linspace(0, 1, 7))
        # colors = ['r', 'b', 'c', 'orange', 'g', 'grey']
        agent_to_plot = 'second_0'  # 'first_0' or 'second_0'
        env_files =[f for f in files if env in f]

        fig= plt.figure(figsize=(8, 5), dpi=300)
        for f, c in zip(env_files, colors):
            try:
                data = load_data(f)
            except:
                print(f"{f} not loaded!")
                break
            method = f.split('v1_')[-1]
            plot(data['episode_reward'], method, c, agent_to_plot, smooth_radius=20)

        plt.legend()
        plt.grid()
        plt.title(f'Exploitation Test-{env}')
        plt.xlabel('Episode')
        plt.ylabel('Exploiter Reward')
        savepath = f'{data_folder}/figs/exploitation_result/'
        os.makedirs(savepath, exist_ok=True)
        savefile = savepath+f'exploit_{idx}_{env}.png'
        plt.savefig(savefile, bbox_inches='tight', )
        # plt.show()
        plt.close()

# %%
env = 'tennis'
folder = '../data/log/20220115_0159_exploit/'
files = ! ls $folder
print(files)
colors = cm.rainbow(np.linspace(0, 1, 7))
# colors = ['r', 'b', 'c', 'orange', 'g', 'grey']
agent_to_plot = 'second_0'  # 'first_0' or 'second_0'
env_files =[f for f in files if env in f]
print(env_files)

for f, c in zip(env_files, colors):
    data = load_data(f)
    method = f.split('v1_')[-1]
    plot(data['episode_reward'], method, c, agent_to_plot, smooth_radius=20)

plt.legend()
plt.grid()
plt.title(f'Exploitation Test-{env}')
plt.xlabel('Episode')
plt.ylabel('Exploiter Reward')
# savepath=f'generated_img/compare_exploitation_{env}.pdf'
# plt.savefig(savepath, bbox_inches='tight',)
# Out:
# ['pettingzoo_boxing_v1_fictitious_selfplay2', 'pettingzoo_boxing_v1_nash_dqn', 'pettingzoo_boxing_v1_nash_dqn_exploiter', 'pettingzoo_boxing_v1_nfsp', 'pettingzoo_boxing_v1_nxdo2', 'pettingzoo_boxing_v1_selfplay2', 'pettingzoo_ice_hockey_v1_fictitious_selfplay2', 'pettingzoo_ice_hockey_v1_nash_dqn', 'pettingzoo_ice_hockey_v1_nash_dqn_exploiter', 'pettingzoo_ice_hockey_v1_nfsp', 'pettingzoo_pong_v2_fictitious_selfplay2', 'pettingzoo_pong_v2_nash_dqn', 'pettingzoo_pong_v2_nash_dqn_exploiter', 'pettingzoo_pong_v2_nfsp', 'pettingzoo_pong_v2_nxdo2', 'pettingzoo_pong_v2_selfplay2', 'pettingzoo_surround_v1_fictitious_selfplay2', 'pettingzoo_surround_v1_nash_dqn', 'pettingzoo_surround_v1_nash_dqn_exploiter', 'pettingzoo_surround_v1_nfsp', 'pettingzoo_surround_v1_nxdo2', 'pettingzoo_surround_v1_selfplay2', 'pettingzoo_tennis_v2_fictitious_selfplay2', 'pettingzoo_tennis_v2_nash_dqn', 'pettingzoo_tennis_v2_nash_dqn_exploiter', 'pettingzoo_tennis_v2_nfsp', 'pettingzoo_tennis_v2_nxdo2', 'pettingzoo_tennis_v2_selfplay2', 'slimevolley_SlimeVolley-v0_fictitious_selfplay2', 'slimevolley_SlimeVolley-v0_nash_dqn', 'slimevolley_SlimeVolley-v0_nash_dqn_exploiter', 'slimevolley_SlimeVolley-v0_nfsp', 'slimevolley_SlimeVolley-v0_nxdo2', 'slimevolley_SlimeVolley-v0_selfplay2']
# ['pettingzoo_tennis_v2_fictitious_selfplay2', 'pettingzoo_tennis_v2_nash_dqn', 'pettingzoo_tennis_v2_nash_dqn_exploiter', 'pettingzoo_tennis_v2_nfsp', 'pettingzoo_tennis_v2_nxdo2', 'pettingzoo_tennis_v2_selfplay2']
# ../data/log/20220115_0159_exploit/pettingzoo_tennis_v2_fictitious_selfplay2
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220115_0159_exploit/pettingzoo_tennis_v2_nash_dqn
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220115_0159_exploit/pettingzoo_tennis_v2_nash_dqn_exploiter
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220115_0159_exploit/pettingzoo_tennis_v2_nfsp
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220115_0159_exploit/pettingzoo_tennis_v2_nxdo2
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220115_0159_exploit/pettingzoo_tennis_v2_selfplay2
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# Text(0, 0.5, 'Exploiter Reward')

# %%
env = 'surround'
folder = '../data/log/20220115_0159_exploit/'
files = ! ls $folder
print(files)
colors = cm.rainbow(np.linspace(0, 1, 7))
# colors = ['r', 'b', 'c', 'orange', 'g', 'grey']
agent_to_plot = 'second_0'  # 'first_0' or 'second_0'
env_files =[f for f in files if env in f]
print(env_files)

for f, c in zip(env_files, colors):
    try:
        data = load_data(f)
        method = f.split('v1_')[-1]
        plot(data['episode_reward'], method, c, agent_to_plot, smooth_radius=20)
    except:
        pass

plt.legend()
plt.grid()
plt.title(f'Exploitation Test-{env}')
plt.xlabel('Episode')
plt.ylabel('Exploiter Reward')
# savepath=f'generated_img/compare_exploitation_{env}.pdf'
# plt.savefig(savepath, bbox_inches='tight',)
# Out:
# ['pettingzoo_boxing_v1_fictitious_selfplay2', 'pettingzoo_boxing_v1_nash_dqn', 'pettingzoo_boxing_v1_nash_dqn_exploiter', 'pettingzoo_boxing_v1_nfsp', 'pettingzoo_boxing_v1_nxdo2', 'pettingzoo_boxing_v1_selfplay2', 'pettingzoo_ice_hockey_v1_fictitious_selfplay2', 'pettingzoo_ice_hockey_v1_nash_dqn', 'pettingzoo_ice_hockey_v1_nash_dqn_exploiter', 'pettingzoo_ice_hockey_v1_nfsp', 'pettingzoo_pong_v2_fictitious_selfplay2', 'pettingzoo_pong_v2_nash_dqn', 'pettingzoo_pong_v2_nash_dqn_exploiter', 'pettingzoo_pong_v2_nfsp', 'pettingzoo_pong_v2_nxdo2', 'pettingzoo_pong_v2_selfplay2', 'pettingzoo_surround_v1_fictitious_selfplay2', 'pettingzoo_surround_v1_nash_dqn', 'pettingzoo_surround_v1_nash_dqn_exploiter', 'pettingzoo_surround_v1_nfsp', 'pettingzoo_surround_v1_nxdo2', 'pettingzoo_surround_v1_selfplay2', 'pettingzoo_tennis_v2_fictitious_selfplay2', 'pettingzoo_tennis_v2_nash_dqn', 'pettingzoo_tennis_v2_nash_dqn_exploiter', 'pettingzoo_tennis_v2_nfsp', 'pettingzoo_tennis_v2_nxdo2', 'pettingzoo_tennis_v2_selfplay2', 'slimevolley_SlimeVolley-v0_fictitious_selfplay2', 'slimevolley_SlimeVolley-v0_nash_dqn', 'slimevolley_SlimeVolley-v0_nash_dqn_exploiter', 'slimevolley_SlimeVolley-v0_nfsp', 'slimevolley_SlimeVolley-v0_nxdo2', 'slimevolley_SlimeVolley-v0_selfplay2']
# ['pettingzoo_surround_v1_fictitious_selfplay2', 'pettingzoo_surround_v1_nash_dqn', 'pettingzoo_surround_v1_nash_dqn_exploiter', 'pettingzoo_surround_v1_nfsp', 'pettingzoo_surround_v1_nxdo2', 'pettingzoo_surround_v1_selfplay2']
# ../data/log/20220115_0159_exploit/pettingzoo_surround_v1_fictitious_selfplay2
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220115_0159_exploit/pettingzoo_surround_v1_nash_dqn
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220115_0159_exploit/pettingzoo_surround_v1_nash_dqn_exploiter
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220115_0159_exploit/pettingzoo_surround_v1_nfsp
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220115_0159_exploit/pettingzoo_surround_v1_nxdo2
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220115_0159_exploit/pettingzoo_surround_v1_selfplay2
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# Text(0, 0.5, 'Exploiter Reward')

# %%
env = 'ice_hockey'
folder = '../data/log/20220115_0159_exploit/'
files = ! ls $folder
print(files)
colors = cm.rainbow(np.linspace(0, 1, 7))
# colors = ['r', 'b', 'c', 'orange', 'g', 'grey']
agent_to_plot = 'second_0'  # 'first_0' or 'second_0'
env_files =[f for f in files if env in f]
print(env_files)

for f, c in zip(env_files, colors):
    data = load_data(f)
    method = f.split('v1_')[-1]
    plot(data['episode_reward'], method, c, agent_to_plot, smooth_radius=20)

plt.legend()
plt.grid()
plt.title(f'Exploitation Test-{env}')
plt.xlabel('Episode')
plt.ylabel('Exploiter Reward')
# savepath=f'generated_img/compare_exploitation_{env}.pdf'
# plt.savefig(savepath, bbox_inches='tight',)
# Out:
# ['pettingzoo_boxing_v1_fictitious_selfplay2', 'pettingzoo_boxing_v1_nash_dqn', 'pettingzoo_boxing_v1_nash_dqn_exploiter', 'pettingzoo_boxing_v1_nfsp', 'pettingzoo_boxing_v1_nxdo2', 'pettingzoo_boxing_v1_selfplay2', 'pettingzoo_ice_hockey_v1_fictitious_selfplay2', 'pettingzoo_ice_hockey_v1_nash_dqn', 'pettingzoo_ice_hockey_v1_nash_dqn_exploiter', 'pettingzoo_ice_hockey_v1_nfsp', 'pettingzoo_pong_v2_fictitious_selfplay2', 'pettingzoo_pong_v2_nash_dqn', 'pettingzoo_pong_v2_nash_dqn_exploiter', 'pettingzoo_pong_v2_nfsp', 'pettingzoo_pong_v2_nxdo2', 'pettingzoo_pong_v2_selfplay2', 'pettingzoo_surround_v1_fictitious_selfplay2', 'pettingzoo_surround_v1_nash_dqn', 'pettingzoo_surround_v1_nash_dqn_exploiter', 'pettingzoo_surround_v1_nfsp', 'pettingzoo_surround_v1_nxdo2', 'pettingzoo_surround_v1_selfplay2', 'pettingzoo_tennis_v2_fictitious_selfplay2', 'pettingzoo_tennis_v2_nash_dqn', 'pettingzoo_tennis_v2_nash_dqn_exploiter', 'pettingzoo_tennis_v2_nfsp', 'pettingzoo_tennis_v2_nxdo2', 'pettingzoo_tennis_v2_selfplay2', 'slimevolley_SlimeVolley-v0_fictitious_selfplay2', 'slimevolley_SlimeVolley-v0_nash_dqn', 'slimevolley_SlimeVolley-v0_nash_dqn_exploiter', 'slimevolley_SlimeVolley-v0_nfsp', 'slimevolley_SlimeVolley-v0_nxdo2', 'slimevolley_SlimeVolley-v0_selfplay2']
# ['pettingzoo_ice_hockey_v1_fictitious_selfplay2', 'pettingzoo_ice_hockey_v1_nash_dqn', 'pettingzoo_ice_hockey_v1_nash_dqn_exploiter', 'pettingzoo_ice_hockey_v1_nfsp']
# ../data/log/20220115_0159_exploit/pettingzoo_ice_hockey_v1_fictitious_selfplay2
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220115_0159_exploit/pettingzoo_ice_hockey_v1_nash_dqn
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220115_0159_exploit/pettingzoo_ice_hockey_v1_nash_dqn_exploiter
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220115_0159_exploit/pettingzoo_ice_hockey_v1_nfsp
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# Text(0, 0.5, 'Exploiter Reward')

# %%
env = 'slimevolley'
folder = '../data/log/20220115_0159_exploit/'
files = ! ls $folder
print(files)
colors = cm.rainbow(np.linspace(0, 1, 7))
# colors = ['r', 'b', 'c', 'orange', 'g', 'grey']
agent_to_plot = 'second_0'  # 'first_0' or 'second_0'
env_files =[f for f in files if env in f]
print(env_files)

for f, c in zip(env_files, colors):
    try:
        data = load_data(f)
        method = f.split('v1_')[-1]
        plot(data['episode_reward'], method, c, agent_to_plot, smooth_radius=20)
    except:
        pass

plt.legend()
plt.grid()
plt.title(f'Exploitation Test-{env}')
plt.xlabel('Episode')
plt.ylabel('Exploiter Reward')
# savepath=f'generated_img/compare_exploitation_{env}.pdf'
# plt.savefig(savepath, bbox_inches='tight',)
# Out:
# ['pettingzoo_boxing_v1_fictitious_selfplay2', 'pettingzoo_boxing_v1_nash_dqn', 'pettingzoo_boxing_v1_nash_dqn_exploiter', 'pettingzoo_boxing_v1_nfsp', 'pettingzoo_boxing_v1_nxdo2', 'pettingzoo_boxing_v1_selfplay2', 'pettingzoo_ice_hockey_v1_fictitious_selfplay2', 'pettingzoo_ice_hockey_v1_nash_dqn', 'pettingzoo_ice_hockey_v1_nash_dqn_exploiter', 'pettingzoo_ice_hockey_v1_nfsp', 'pettingzoo_pong_v2_fictitious_selfplay2', 'pettingzoo_pong_v2_nash_dqn', 'pettingzoo_pong_v2_nash_dqn_exploiter', 'pettingzoo_pong_v2_nfsp', 'pettingzoo_pong_v2_nxdo2', 'pettingzoo_pong_v2_selfplay2', 'pettingzoo_surround_v1_fictitious_selfplay2', 'pettingzoo_surround_v1_nash_dqn', 'pettingzoo_surround_v1_nash_dqn_exploiter', 'pettingzoo_surround_v1_nfsp', 'pettingzoo_surround_v1_nxdo2', 'pettingzoo_surround_v1_selfplay2', 'pettingzoo_tennis_v2_fictitious_selfplay2', 'pettingzoo_tennis_v2_nash_dqn', 'pettingzoo_tennis_v2_nash_dqn_exploiter', 'pettingzoo_tennis_v2_nfsp', 'pettingzoo_tennis_v2_nxdo2', 'pettingzoo_tennis_v2_selfplay2', 'slimevolley_SlimeVolley-v0_fictitious_selfplay2', 'slimevolley_SlimeVolley-v0_nash_dqn', 'slimevolley_SlimeVolley-v0_nash_dqn_exploiter', 'slimevolley_SlimeVolley-v0_nfsp', 'slimevolley_SlimeVolley-v0_nxdo2', 'slimevolley_SlimeVolley-v0_selfplay2']
# ['slimevolley_SlimeVolley-v0_fictitious_selfplay2', 'slimevolley_SlimeVolley-v0_nash_dqn', 'slimevolley_SlimeVolley-v0_nash_dqn_exploiter', 'slimevolley_SlimeVolley-v0_nfsp', 'slimevolley_SlimeVolley-v0_nxdo2', 'slimevolley_SlimeVolley-v0_selfplay2']
# ../data/log/20220115_0159_exploit/slimevolley_SlimeVolley-v0_fictitious_selfplay2
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220115_0159_exploit/slimevolley_SlimeVolley-v0_nash_dqn
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220115_0159_exploit/slimevolley_SlimeVolley-v0_nash_dqn_exploiter
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220115_0159_exploit/slimevolley_SlimeVolley-v0_nfsp
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220115_0159_exploit/slimevolley_SlimeVolley-v0_nxdo2
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220115_0159_exploit/slimevolley_SlimeVolley-v0_selfplay2
# Text(0, 0.5, 'Exploiter Reward')
