# %%
folder = '../data/log/'
files = ! ls $folder
# print(files)

# %%
import json

def load_data(file_name, log='update_log'):
    file_dir = folder+files[0]
    file_dir = folder+file_name
    print(file_dir)
    
    data = json.load( open(file_dir+f"/{log}.json"))
    print(data.keys())
    return data

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['savefig.facecolor']='white'

def plot(data, label='reward', smooth_radius=200, savepath=None, range=10**8):
    plt.clf()
    def smooth(y, radius=200, mode='two_sided'):
        if len(y) < 2*radius+1:
            return np.ones_like(y) * y.mean()
        elif mode == 'two_sided':
            convkernel = np.ones(2 * radius+1)
            return np.convolve(y, convkernel, mode='same') / \
                   np.convolve(np.ones_like(y), convkernel, mode='same')
        elif mode == 'causal':
            convkernel = np.ones(radius)
            out = np.convolve(y, convkernel,mode='full') / \
                  np.convolve(np.ones_like(y), convkernel, mode='full')
            return out[:-radius+1]

    colors = ['r', 'b', 'c', 'y']
    
    for (k, v), c in zip(data.items(), colors):
        v=np.array(v)
        plt.plot(smooth(v[:range], radius=smooth_radius), color=c, label=k)
        plt.plot(v[:range], color=c, alpha=0.3)
    plt.legend()
    plt.grid()
    plt.title(label)
    plt.xlabel('episode')
    plt.ylabel(label)
    if savepath is not None:
        plt.savefig(savepath, bbox_inches='tight',)

def plot_with_x(x, data, label='reward', smooth_radius=200, savepath=None, range=10**8):
    plt.clf()
    def smooth(y, radius=200, mode='two_sided'):
        if len(y) < 2*radius+1:
            return np.ones_like(y) * y.mean()
        elif mode == 'two_sided':
            convkernel = np.ones(2 * radius+1)
            return np.convolve(y, convkernel, mode='same') / \
                   np.convolve(np.ones_like(y), convkernel, mode='same')
        elif mode == 'causal':
            convkernel = np.ones(radius)
            out = np.convolve(y, convkernel,mode='full') / \
                  np.convolve(np.ones_like(y), convkernel, mode='full')
            return out[:-radius+1]

    colors = ['r', 'b', 'c', 'y']
    
    for (k, v), c in zip(data.items(), colors):
        v=np.array(v)
        plt.plot(x, smooth(v[:range], radius=smooth_radius), color=c, label=k)
        plt.plot(x, v[:range], color=c, alpha=0.3)
    plt.legend()
    plt.grid()
    plt.title(label)
    plt.xlabel('episode')
    plt.ylabel(label)
    if savepath is not None:
        plt.savefig(savepath, bbox_inches='tight',)
    
img_path = 'generated_img/'

# %%
# a first unexploitable agent by sp on boxing
file_name =  '20220418_2045_exploit/pettingzoo_boxing_v1_nash_dqn/'
data = load_data(file_name, log='eval')
# print(data['loss'].keys())
plot(data['episode_reward'], 'episode_reward', smooth_radius=20, savepath='loss.png')
plt.show()

data = load_data(file_name, log='process')
# print(data['loss'].keys())
plot(data['episode_reward'], 'episode_reward', smooth_radius=20, savepath='loss.png')
plt.show()
# Out:
# ../data/log/20220418_2045_exploit/pettingzoo_boxing_v1_nash_dqn/
# dict_keys(['episode', 'episode_reward'])
# ../data/log/20220418_2045_exploit/pettingzoo_boxing_v1_nash_dqn/
# dict_keys(['episode_reward', 'loss', 'episode_length'])

# %%
# a first unexploitable agent by sp on boxing
file_name =  '20220418_2045_exploit_second/pettingzoo_boxing_v1_nash_dqn/'
data = load_data(file_name, log='eval')
# print(data['loss'].keys())
plot(data['episode_reward'], 'episode_reward', smooth_radius=20, savepath='loss.png')
plt.show()

data = load_data(file_name, log='process')
# print(data['loss'].keys())
plot(data['episode_reward'], 'episode_reward', smooth_radius=20, savepath='loss.png')
plt.show()
# Out:
# ../data/log/20220418_2045_exploit_second/pettingzoo_boxing_v1_nash_dqn/
# dict_keys(['episode', 'episode_reward'])
# ../data/log/20220418_2045_exploit_second/pettingzoo_boxing_v1_nash_dqn/
# dict_keys(['episode_reward', 'loss', 'episode_length'])

# %%
# a first unexploitable agent by sp on boxing
file_name =  '20220418_2045_exploit/pettingzoo_tennis_v2_nash_dqn/'
data = load_data(file_name, log='eval')
# print(data['loss'].keys())
plot(data['episode_reward'], 'episode_reward', smooth_radius=100, savepath='loss.png')
plt.show()

data = load_data(file_name, log='process')
# print(data['loss'].keys())
plot(data['episode_reward'], 'episode_reward', smooth_radius=100, savepath='loss.png')
plt.show()
# Out:
# ../data/log/20220418_2045_exploit/pettingzoo_tennis_v2_nash_dqn/
# dict_keys(['episode', 'episode_reward'])
# ../data/log/20220418_2045_exploit/pettingzoo_tennis_v2_nash_dqn/
# dict_keys(['episode_reward', 'loss', 'episode_length'])

# %%
# a first unexploitable agent by sp on boxing
file_name =  '20220418_2045_exploit_second/pettingzoo_tennis_v2_nash_dqn/'
data = load_data(file_name, log='eval')
# print(data['loss'].keys())
plot(data['episode_reward'], 'episode_reward', smooth_radius=100, savepath='loss.png')
plt.show()

data = load_data(file_name, log='process')
# print(data['loss'].keys())
plot(data['episode_reward'], 'episode_reward', smooth_radius=100, savepath='loss.png')
plt.show()
# Out:
# ../data/log/20220418_2045_exploit_second/pettingzoo_tennis_v2_nash_dqn/
# dict_keys(['episode', 'episode_reward'])
# ../data/log/20220418_2045_exploit_second/pettingzoo_tennis_v2_nash_dqn/
# dict_keys(['episode_reward', 'loss', 'episode_length'])

# %%
# a first unexploitable agent by sp on boxing
file_name =  '20220418_2045_exploit/slimevolley_SlimeVolley-v0_nash_dqn/'
data = load_data(file_name, log='eval')
# print(data['loss'].keys())
plot(data['episode_reward'], 'episode_reward', smooth_radius=100, savepath='loss.png')
plt.show()

data = load_data(file_name, log='process')
# print(data['loss'].keys())
plot(data['episode_reward'], 'episode_reward', smooth_radius=100, savepath='loss.png')
plt.show()
# Out:
# ../data/log/20220418_2045_exploit/slimevolley_SlimeVolley-v0_nash_dqn/
# dict_keys(['episode', 'episode_reward'])
# ../data/log/20220418_2045_exploit/slimevolley_SlimeVolley-v0_nash_dqn/
# dict_keys(['episode_reward', 'loss', 'episode_length'])

# %%
# a first unexploitable agent by sp on boxing
file_name =  '20220418_2045_exploit_second/slimevolley_SlimeVolley-v0_nash_dqn/'
data = load_data(file_name, log='eval')
# print(data['loss'].keys())
plot(data['episode_reward'], 'episode_reward', smooth_radius=100, savepath='loss.png')
plt.show()

data = load_data(file_name, log='process')
# print(data['loss'].keys())
plot(data['episode_reward'], 'episode_reward', smooth_radius=100, savepath='loss.png')
plt.show()
# Out:
# ../data/log/20220418_2045_exploit_second/slimevolley_SlimeVolley-v0_nash_dqn/
# dict_keys(['episode', 'episode_reward'])
# ../data/log/20220418_2045_exploit_second/slimevolley_SlimeVolley-v0_nash_dqn/
# dict_keys(['episode_reward', 'loss', 'episode_length'])

# %%
file_name =  '20220405_1609_exploit/pettingzoo_boxing_v1_nash_dqn_factorized'
data = load_data(file_name, 'process')
plot(data['episode_reward'], 'episode_reward', smooth_radius=20, savepath='reward.png')
plt.show()
# Out:
# ../data/log/20220405_1609_exploit/pettingzoo_boxing_v1_nash_dqn_factorized
# dict_keys(['episode_reward', 'loss', 'episode_length'])

# %%
file_name =  '20220405_1609_exploit_second/pettingzoo_boxing_v1_nash_dqn'
data = load_data(file_name, 'process')
plot(data['episode_reward'], 'episode_reward', smooth_radius=20, savepath='reward.png')
plt.show()

data = load_data(file_name, 'eval')
plot_with_x(data['episode'], data['episode_reward'], 'episode_reward', smooth_radius=20, savepath='reward.png')
plt.show()
# Out:
# ../data/log/20220405_1609_exploit_second/pettingzoo_boxing_v1_nash_dqn
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220405_1609_exploit_second/pettingzoo_boxing_v1_nash_dqn
# dict_keys(['episode', 'episode_reward'])

# %%
import os

index = '20220421_1859'
exploited_models = ['first', 'second']
envs = ['pettingzoo_boxing_v1', 'pettingzoo_tennis_v2', 'pettingzoo_pong_v2', 'pettingzoo_ice_hockey_v1', 'slimevolley_SlimeVolley-v0']
path = f'../data/figs/{index}/'
os.makedirs(path, exist_ok = True)

for exploited_model in exploited_models:
    for env in envs:
        file_name =  f'{index}_exploit_{exploited_model}/{env}_nash_dqn'
        data = load_data(file_name, 'process')
        plot(data['episode_reward'], 'episode_reward', smooth_radius=100, savepath=path+f'{env}_exploit_{exploited_model}_nogreedy.png')
        # plt.show()

        data = load_data(file_name, 'eval')
        plot_with_x(data['episode'], data['episode_reward'], 'episode_reward', smooth_radius=20, savepath=path+f'{env}_exploit_{exploited_model}_greedy.png')
        # plt.show()
# Out:
# ../data/log/20220421_1859_exploit_first/pettingzoo_boxing_v1_nash_dqn
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220421_1859_exploit_first/pettingzoo_boxing_v1_nash_dqn
# dict_keys(['episode', 'episode_reward'])
# ../data/log/20220421_1859_exploit_first/pettingzoo_tennis_v2_nash_dqn
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220421_1859_exploit_first/pettingzoo_tennis_v2_nash_dqn
# dict_keys(['episode', 'episode_reward'])
# ../data/log/20220421_1859_exploit_first/pettingzoo_pong_v2_nash_dqn
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220421_1859_exploit_first/pettingzoo_pong_v2_nash_dqn
# dict_keys(['episode', 'episode_reward'])
# ../data/log/20220421_1859_exploit_first/pettingzoo_ice_hockey_v1_nash_dqn
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220421_1859_exploit_first/pettingzoo_ice_hockey_v1_nash_dqn
# dict_keys(['episode', 'episode_reward'])
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['savefig.facecolor']='white'

def compare_plot(data, label='reward', smooth_radius=200, savepath=None, range=10**8):
    plt.clf()
    def smooth(y, radius=200, mode='two_sided'):
        if len(y) < 2*radius+1:
            return np.ones_like(y) * y.mean()
        elif mode == 'two_sided':
            convkernel = np.ones(2 * radius+1)
            return np.convolve(y, convkernel, mode='same') / \
                   np.convolve(np.ones_like(y), convkernel, mode='same')
        elif mode == 'causal':
            convkernel = np.ones(radius)
            out = np.convolve(y, convkernel,mode='full') / \
                  np.convolve(np.ones_like(y), convkernel, mode='full')
            return out[:-radius+1]

    colors = ['r', 'b', 'c', 'y']
    
    for (k, v), c in zip(data.items(), colors):
        v=np.array(v)
        plt.plot(smooth(v[:range], radius=smooth_radius), color=c, label=k)
        plt.plot(v[:range], color=c, alpha=0.3)
    plt.legend()
    plt.grid()
    plt.title(label)
    plt.xlabel('episode')
    plt.ylabel('reward')
    if savepath is not None:
        plt.savefig(savepath, bbox_inches='tight',)
    
img_path = 'generated_img/'

# %%
folder = '../data/log/20220409_1833_exploit/'

files = !ls $folder
print(files)

envs = ['pettingzoo_boxing_v1', 'pettingzoo_combat_tank_v1', 'pettingzoo_ice_hockey_v1', \
    'pettingzoo_pong_v2', 'pettingzoo_surround_v1', 'pettingzoo_tennis_v2', 'slimevolley_SlimeVolley-v0']
methods = ['nash_dqn', 'nash_dqn_exploiter', 'nash_dqn_factorized']

for e in envs:
    data_of_methods = {}
    for m in methods:
        try:
            data = load_data(e+'_'+m)
            data_of_methods[m] = data['episode_reward']['second_0']
        except:
            print(f'{e}_{m} not loaded!')
    compare_plot(data_of_methods, label=e, savepath=f'20220409_1833_exploit/{e}')
# Out:
# ['pettingzoo_boxing_v1_nash_dqn', 'pettingzoo_boxing_v1_nash_dqn_exploiter', 'pettingzoo_boxing_v1_nash_dqn_factorized', 'pettingzoo_combat_tank_v1_nash_dqn', 'pettingzoo_combat_tank_v1_nash_dqn_exploiter', 'pettingzoo_combat_tank_v1_nash_dqn_factorized', 'pettingzoo_ice_hockey_v1_nash_dqn', 'pettingzoo_ice_hockey_v1_nash_dqn_exploiter', 'pettingzoo_ice_hockey_v1_nash_dqn_factorized', 'pettingzoo_pong_v2_nash_dqn', 'pettingzoo_pong_v2_nash_dqn_exploiter', 'pettingzoo_surround_v1_nash_dqn', 'pettingzoo_surround_v1_nash_dqn_factorized', 'pettingzoo_tennis_v2_nash_dqn', 'pettingzoo_tennis_v2_nash_dqn_exploiter', 'pettingzoo_tennis_v2_nash_dqn_factorized', 'slimevolley_SlimeVolley-v0_nash_dqn', 'slimevolley_SlimeVolley-v0_nash_dqn_exploiter', 'slimevolley_SlimeVolley-v0_nash_dqn_factorized']
# ../data/log/20220409_1833_exploit/pettingzoo_boxing_v1_nash_dqn
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ...

# %%
import os

model_id = '20220412_1654_exploit'
folder = f'../data/log/{model_id}/'
os.makedirs(model_id, exist_ok=True)

files = !ls $folder
print(files)

envs = ['pettingzoo_boxing_v1', 'pettingzoo_pong_v2', 'pettingzoo_surround_v1', 'pettingzoo_tennis_v2']
methods = ['nash_dqn']

for e in envs:
    data_of_methods = {}
    for m in methods:
        try:
            data = load_data(e+'_'+m)
            data_of_methods[m] = data['episode_reward']['second_0']
        except:
            print(f'{e}_{m} not loaded!')
    compare_plot(data_of_methods, label=e, savepath=f'{model_id}/{e}')
# Out:
# ['pettingzoo_boxing_v1_nash_dqn', 'pettingzoo_pong_v2_nash_dqn', 'pettingzoo_surround_v1_nash_dqn', 'pettingzoo_tennis_v2_nash_dqn']
# ../data/log/20220412_1654_exploit/pettingzoo_boxing_v1_nash_dqn
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220412_1654_exploit/pettingzoo_pong_v2_nash_dqn
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220412_1654_exploit/pettingzoo_surround_v1_nash_dqn
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220412_1654_exploit/pettingzoo_tennis_v2_nash_dqn
# dict_keys(['episode_reward', 'loss', 'episode_length'])

# %%
import os

model_id = '20220412_1700_exploit'
folder = f'../data/log/{model_id}/'
os.makedirs(model_id, exist_ok=True)

files = !ls $folder
print(files)

envs = ['pettingzoo_boxing_v1', 'pettingzoo_pong_v2', 'pettingzoo_surround_v1', 'pettingzoo_tennis_v2']
methods = ['nash_dqn']

for e in envs:
    data_of_methods = {}
    for m in methods:
        try:
            data = load_data(e+'_'+m)
            data_of_methods[m] = data['episode_reward']['second_0']
        except:
            print(f'{e}_{m} not loaded!')
    compare_plot(data_of_methods, label=e, savepath=f'{model_id}/{e}')
# Out:
# ['pettingzoo_boxing_v1_nash_dqn', 'pettingzoo_pong_v2_nash_dqn', 'pettingzoo_surround_v1_nash_dqn', 'pettingzoo_tennis_v2_nash_dqn']
# ../data/log/20220412_1700_exploit/pettingzoo_boxing_v1_nash_dqn
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220412_1700_exploit/pettingzoo_pong_v2_nash_dqn
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220412_1700_exploit/pettingzoo_surround_v1_nash_dqn
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220412_1700_exploit/pettingzoo_tennis_v2_nash_dqn
# dict_keys(['episode_reward', 'loss', 'episode_length'])
