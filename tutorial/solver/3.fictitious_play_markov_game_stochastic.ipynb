# %% [markdown]
# # Extensive Fictitious Play (XFP)
# This tutorial  demonstrates extensive fictitious play (XFP) on a zero-sum Markov game, which is more general than extensive-from game (more general than normal-form game).
#
# For the payoff matrix, row player is maximizer, coloumn player is minimizer.
#
# Reference: http://proceedings.mlr.press/v37/heinrich15.html

# %%
import sys
sys.path.append("../..")
from mars.env.mdp import ArbitraryMDP, MDPWrapper
import numpy as np

num_states = 3
num_actions_per_player = 3
num_trans = 3

env = MDPWrapper(ArbitraryMDP(num_states=num_states, num_actions_per_player=num_actions_per_player, num_trans=num_trans))
trans_matrices = env.env.trans_prob_matrices # shape: [dim_transition, dim_state, dim_action (p1*p2), dim_state]
reward_matrices = env.env.reward_matrices # shape: [dim_transition, dim_state, dim_action (p1*p2), dim_state]

oracle_nash_v, oracle_nash_q, oracle_nash_strategies = env.NEsolver(verbose=False)
oracle_v_star = oracle_nash_v[0]

oracle_v_star = np.mean(oracle_v_star, axis=0)
print(env.observation_space, env.action_space)
# env.render()
obs = env.reset()
print(obs)
done = False
while not np.any(done):
    obs, r, done, _ = env.step([1,0])
    print(obs, r, done)
print('Average initial state value of oracle Nash equilibrium for the first player: ', oracle_v_star)
# Out:
# Box(0.0, 12.0, (1,), float32) Discrete(3)
# [[0], [0]]
# [[5], [5]] [0.5610583525729109, -0.5610583525729109] [False, False]
# [[6], [6]] [-0.7261994566288021, 0.7261994566288021] [False, False]
# [[9], [9]] [-0.8460871060267345, 0.8460871060267345] [True, True]
# Average initial state value of oracle Nash equilibrium for the first player:  -0.29607107415447115
# /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages/ecos/ecos.py:26: UserWarning: Converting G to a CSC matrix; may take a while.
#   warn("Converting G to a CSC matrix; may take a while.")
# /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages/ecos/ecos.py:29: UserWarning: Converting A to a CSC matrix; may take a while.
#   warn("Converting A to a CSC matrix; may take a while.")

# %%
print(np.array(oracle_nash_strategies).shape)
oracle_max_policy = np.array(oracle_nash_strategies)[:, :, 0, :]
print(oracle_max_policy.shape)
# Out:
# (3, 3, 2, 3)
# (3, 3, 3)

# %%
# test 

def create_expand_Q():
    """
    Returns:
    [   [state_dim, action_dim, action_dim],
        [state_dim, action_dim, action_dim, state_dim, action_dim, action_dim],
        [state_dim, action_dim, action_dim, state_dim, action_dim, action_dim, state_dim, action_dim, action_dim],
        ...
    ]
    """
    values = []
    intial_dim = [num_states, num_actions_per_player, num_actions_per_player]
    for i in range(num_trans):
        value =  (1./num_actions_per_player) * np.ones(intial_dim)
        # incremental shape
        intial_dim.extend([num_states, num_actions_per_player, num_actions_per_player])
        values.append(value)

    return values

def create_expand_policy():
    """
    Returns:
    [   [state_dim, action_dim],
        [state_dim, action_dim, action_dim, state_dim, action_dim],
        [state_dim, action_dim, action_dim, state_dim, action_dim, action_dim, state_dim, action_dim],
        ...
    ]
    """
    policies = []
    intial_dim = [num_states]
    for i in range(num_trans):
        policy =  (1./num_actions_per_player) * np.ones((*intial_dim, num_actions_per_player))
        # incremental shape
        intial_dim.extend([num_actions_per_player, num_actions_per_player, num_states])
        policies.append(policy)

    return policies

def create_expand_value():
    """
    Returns:
    [   [state_dim],
        [state_dim, action_dim, action_dim, state_dim],
        [state_dim, action_dim, action_dim, state_dim, action_dim, action_dim, state_dim],
        ...
    ]    
    """
    values = []
    intial_dim = [num_states]
    for i in range(num_trans):
        value =  (1./num_actions_per_player) * np.ones(intial_dim)
        # incremental shape
        intial_dim.extend([num_actions_per_player, num_actions_per_player, num_states])
        values.append(value)

    return values

def broadcast_shape(input, output_shape):
    """ broadcast input to have the same shape as output_to_be """
    len_input_shape = len(np.array(input).shape)
    incrs_shape = output_shape[:-len_input_shape]+len_input_shape*(1,)
    output = np.tile(input, incrs_shape)
    return output



def best_response_value(trans_prob_matrices, reward_matrices, policy, num_actions, side='max'):
    """
    Formulas for calculating best response values:
    1. Nash strategies: (\pi_a^*, \pi_b^*) = \min \max Q(s,a,b), 
        where Q(s,a,b) = r(s,a,b) + \gamma \min \max Q(s',a',b') (this is the definition of Nash Q-value);
    2. Best response (of max player) value: Br V(s) = \min_b \pi(s,a) Br Q(s,a,b)  (Br Q is the oracle best response Q value)
    """
    br_v = create_expand_value()
    br_q = create_expand_Q()

    for i in range(num_trans-1, -1, -1):  # inverse indexing
        tm = trans_matrices[i]
        rm = reward_matrices[i]

        rm_ = np.array(rm).reshape(num_states, num_actions_per_player, num_actions_per_player, num_states)
        tm_ = np.array(tm).reshape(num_states, num_actions_per_player, num_actions_per_player, num_states)
        expand_rm = broadcast_shape(rm_, br_q[i].shape+(num_states,))
        if i == num_trans-1:
            expand_tm = broadcast_shape(tm_, expand_rm.shape)
            br_q[i] =  np.sum(expand_rm*expand_tm, axis=-1)
        else:
            print(br_v[i+1])
            v = br_v[i+1]
            v_before_trans = expand_rm + v  # expand_rm and v are same shape
            expand_tm = broadcast_shape(tm_, v_before_trans.shape)  # get the same shape as v_before_trans
            br_q[i] = np.sum(v_before_trans*expand_tm, axis=-1)  # only sum over last dim: state

        if side == 'max':
            mu_dot_q = np.einsum('...i, ...ij->...j', policy[i], br_q[i])
            br_v[i] = np.min(mu_dot_q, axis=-1)
        else:
            q_dot_nu = np.einsum('...ij, ...j->...i', br_q[i], policy[i])
            br_v[i] = np.max(q_dot_nu, axis=-1)         

    avg_init_br_v = -np.mean(br_v[0])  # average best response value of initial states; minus for making it positive
    return avg_init_br_v

expand_p = create_expand_policy()
test_p=[] # make the oracle nash to be expand policy shape
for p, o in zip(expand_p, oracle_max_policy):
    tp = broadcast_shape(o, p.shape)
    print(tp.shape)
    test_p.append(tp)
    
best_response_value(trans_matrices, reward_matrices, test_p, num_actions_per_player)
# Out:
# (3, 3)
# (3, 3, 3, 3, 3)
# (3, 3, 3, 3, 3, 3, 3, 3)
# [[[[[[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]]
#
#
#
#    [[[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]]
#
#
#
#    [[[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]]]
#
#
#
#
#   [[[[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]]
#
#
#
#    [[[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]]
#
#
#
#    [[[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]]]
#
#
#
#
#   [[[[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]]
#
#
#
#    [[[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]]
#
#
#
#    [[[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]]]]
#
#
#
#
#
#  [[[[[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]]
#
#
#
#    [[[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]]
#
#
#
#    [[[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]]]
#
#
#
#
#   [[[[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]]
#
#
#
#    [[[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]]
#
#
#
#    [[[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]]]
#
#
#
#
#   [[[[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]]
#
#
#
#    [[[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]]
#
#
#
#    [[[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]]]]
#
#
#
#
#
#  [[[[[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]]
#
#
#
#    [[[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]]
#
#
#
#    [[[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]]]
#
#
#
#
#   [[[[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]]
#
#
#
#    [[[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]]
#
#
#
#    [[[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]]]
#
#
#
#
#   [[[[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]]
#
#
#
#    [[[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]]
#
#
#
#    [[[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]
#
#
#     [[[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]
#
#      [[ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]
#       [ 0.05124187 -0.17762759  0.28158846]]]]]]]
# [[[[-0.03005737 -0.09290083 -0.31685028]
#    [-0.03005737 -0.09290083 -0.31685028]
#    [-0.03005737 -0.09290083 -0.31685028]]
#
#   [[-0.03005737 -0.09290083 -0.31685028]
#    [-0.03005737 -0.09290083 -0.31685028]
#    [-0.03005737 -0.09290083 -0.31685028]]
#
#   [[-0.03005737 -0.09290083 -0.31685028]
#    [-0.03005737 -0.09290083 -0.31685028]
#    [-0.03005737 -0.09290083 -0.31685028]]]
#
#
#  [[[-0.03005737 -0.09290083 -0.31685028]
#    [-0.03005737 -0.09290083 -0.31685028]
#    [-0.03005737 -0.09290083 -0.31685028]]
#
#   [[-0.03005737 -0.09290083 -0.31685028]
#    [-0.03005737 -0.09290083 -0.31685028]
#    [-0.03005737 -0.09290083 -0.31685028]]
#
#   [[-0.03005737 -0.09290083 -0.31685028]
#    [-0.03005737 -0.09290083 -0.31685028]
#    [-0.03005737 -0.09290083 -0.31685028]]]
#
#
#  [[[-0.03005737 -0.09290083 -0.31685028]
#    [-0.03005737 -0.09290083 -0.31685028]
#    [-0.03005737 -0.09290083 -0.31685028]]
#
#   [[-0.03005737 -0.09290083 -0.31685028]
#    [-0.03005737 -0.09290083 -0.31685028]
#    [-0.03005737 -0.09290083 -0.31685028]]
#
#   [[-0.03005737 -0.09290083 -0.31685028]
#    [-0.03005737 -0.09290083 -0.31685028]
#    [-0.03005737 -0.09290083 -0.31685028]]]]
# 0.2960710744766214

# %%
import copy

def sample_from_categorical(dist):
    """
    sample once from a categorical distribution, return the entry index.
    dist: should be a list or array of probabilities for a categorical distribution
    """
    sample_id = np.argmax(np.random.multinomial(1, dist))
    sample_prob = dist[sample_id]
    return sample_id, sample_prob

def unified_state(s):
    unified_s = s[0]%num_states
    return unified_s

# def get_sequence_encoding_id(observed_seq):
#     # sequence encoding id = s1 + a1*S + a2*S*A + s2*S*A*A + a2*S*A*A*S + ...
#     id = 0
#     coef = 1
#     coef_multipliers = [num_states, num_actions_per_player, num_actions_per_player]
#     len_coef_multipliers = len(coef_multipliers)
#     j = 0
#     for o in observed_seq:
#         id += coef * o
#         coef = coef*coef_multipliers[j%len_coef_multipliers]
#     return id

def create_expand_policy(zero_ini=False):
    """
    Returns:
    [   [state_dim, action_dim],
        [state_dim, action_dim, action_dim, state_dim, action_dim],
        [state_dim, action_dim, action_dim, state_dim, action_dim, action_dim, state_dim, action_dim],
        ...
    ]
    """
    policies = []
    intial_dim = [num_states]
    for i in range(num_trans):
        if zero_ini:
            policy =  (1./num_actions_per_player) * np.zeros((*intial_dim, num_actions_per_player))
        else:
            policy =  (1./num_actions_per_player) * np.ones((*intial_dim, num_actions_per_player))
        # incremental shape
        intial_dim.extend([num_actions_per_player, num_actions_per_player, num_states])
        policies.append(policy)

    return policies

def create_expand_value():
    """
    Returns:
    [   [state_dim],
        [state_dim, action_dim, action_dim, state_dim],
        [state_dim, action_dim, action_dim, state_dim, action_dim, action_dim, state_dim],
        ...
    ]    
    """
    values = []
    intial_dim = [num_states]
    for i in range(num_trans):
        value =  (1./num_actions_per_player) * np.ones(intial_dim)
        # incremental shape
        intial_dim.extend([num_actions_per_player, num_actions_per_player, num_states])
        values.append(value)

    return values

def create_expand_Q():
    """
    Returns:
    [   [state_dim, action_dim, action_dim],
        [state_dim, action_dim, action_dim, state_dim, action_dim, action_dim],
        [state_dim, action_dim, action_dim, state_dim, action_dim, action_dim, state_dim, action_dim, action_dim],
        ...
    ]
    """
    values = []
    intial_dim = [num_states, num_actions_per_player, num_actions_per_player]
    for i in range(num_trans):
        value =  (1./num_actions_per_player) * np.ones(intial_dim)
        # incremental shape
        intial_dim.extend([num_states, num_actions_per_player, num_actions_per_player])
        values.append(value)

    return values

def get_posterior_policy(policy_set, meta_prior, likelihood, con_seq, only_update_observed=True):
    posterior_policy = create_expand_policy(zero_ini=True)  # zero initiate to sum later
    num_policies = len(policy_set)
    denom = meta_prior @ likelihood  # [#policy] * [#policy, H] -> [H]
    if only_update_observed:  # only update observed sequences, others use prior
        for pi_i, rho_i in zip(policy_set, meta_prior):  # loop over policy
            for i, (p,) in enumerate(zip(pi_i)): # loop over transition 
                posterior_policy[i] += np.array(p*rho_i)  # all entries using prior

        for pi_i in policy_set:  # loop over policy
            for i, s in enumerate(con_seq): # loop over transition 
                posterior_policy[i][tuple(s)] = 0  # clear the observed entries

        for pi_i, rho_i, likelihood_per_policy in zip(policy_set, meta_prior, likelihood):  # loop over policy
            for i, (p, d, l, s) in enumerate(zip(pi_i, denom, likelihood_per_policy, con_seq)): # loop over transition 
                posterior_policy[i][tuple(s)] += np.array(p[tuple(s)]*rho_i*l/d)  # only update observed

    else:  # update all entries
        for pi_i, rho_i, likelihood_per_policy in zip(policy_set, meta_prior, likelihood):  # loop over policy
            for i, (p, d, l) in enumerate(zip(pi_i, denom, likelihood_per_policy)): # loop over transition
                posterior_policy[i] += np.array(p*rho_i*l/d)  # sum over policies in mixture

    return posterior_policy

def get_prior_policy(policy_set, meta_prior,):
    prior_policy = create_expand_policy(zero_ini=True)  # zero initiate to sum later
    num_policies = len(policy_set)
    for pi_i, rho_i in zip(policy_set, meta_prior):  # loop over policy
        for i, (p,) in enumerate(zip(pi_i)): # loop over transition 
            prior_policy[i] += np.array(p*rho_i)  # all entries using prior
    return prior_policy

def broadcast_shape(input, output_shape):
    """ broadcast input to have the same shape as output_to_be """
    len_input_shape = len(np.array(input).shape)
    incrs_shape = output_shape[:-len_input_shape]+len_input_shape*(1,)
    output = np.tile(input, incrs_shape)
    return output

def get_best_response_policy(player, prob_seq, con_seq):
    given_policy = get_posterior_policy(player['policy_set'], player['meta_strategy'], prob_seq, con_seq)
    br_policy = create_expand_policy()  # best response policy
    br_v = create_expand_value()
    br_q = create_expand_Q()

    for i in range(num_trans-1, -1, -1):  # inverse indexing
        tm = trans_matrices[i]
        rm = reward_matrices[i]

        rm_ = np.array(rm).reshape(num_states, num_actions_per_player, num_actions_per_player, num_states)
        tm_ = np.array(tm).reshape(num_states, num_actions_per_player, num_actions_per_player, num_states)

        expand_rm = broadcast_shape(rm_, br_q[i].shape+(num_states,))  # broadcast the shape of reward matrix to be expand Q shape plus additional state dimension
        if i == num_trans-1:
            expand_tm = broadcast_shape(tm_, expand_rm.shape)
            br_q[i] =  np.sum(expand_rm*expand_tm, axis=-1)
        else:
            v = br_v[i+1]
            v_before_trans = expand_rm + v  # expand_rm and v are same shape
            expand_tm = broadcast_shape(tm_, v_before_trans.shape)  # get the same shape as v_before_trans
            br_q[i] = np.sum(v_before_trans*expand_tm, axis=-1)  # only sum over last dim: state

        if player['side'] == 'max':
            mu_dot_q = np.einsum('...i, ...ij->...j', given_policy[i], br_q[i])
            arg_id = np.argmin(mu_dot_q, axis=-1)  # min player takes minimum as best response against max player's policy
            br_v[i] = np.min(mu_dot_q, axis=-1)
        else:
            q_dot_nu = np.einsum('...ij, ...j->...i', br_q[i], given_policy[i])
            arg_id = np.argmax(q_dot_nu, axis=-1)   # vice versa    
            br_v[i] = np.max(q_dot_nu, axis=-1)     
        
        br_policy[i] = (np.arange(num_actions_per_player) == arg_id[...,None]).astype(int)  # from extreme (min/max) idx to one-hot simplex
        # print(br_policy[i].shape, br_q[i].shape)

    return br_policy

def best_response_value(trans_prob_matrices, reward_matrices, policy, num_actions, side='max'):
    """
    Formulas for calculating best response values:
    1. Nash strategies: (\pi_a^*, \pi_b^*) = \min \max Q(s,a,b), 
        where Q(s,a,b) = r(s,a,b) + \gamma \min \max Q(s',a',b') (this is the definition of Nash Q-value);
    2. Best response (of max player) value: Br V(s) = \min_b \pi(s,a) Br Q(s,a,b)  (Br Q is the oracle best response Q value)
    """
    br_v = create_expand_value()
    br_q = create_expand_Q()

    for i in range(num_trans-1, -1, -1):  # inverse indexing
        tm = trans_matrices[i]
        rm = reward_matrices[i]

        rm_ = np.array(rm).reshape(num_states, num_actions_per_player, num_actions_per_player, num_states)
        tm_ = np.array(tm).reshape(num_states, num_actions_per_player, num_actions_per_player, num_states)
        expand_rm = broadcast_shape(rm_, br_q[i].shape+(num_states,))
        if i == num_trans-1:
            expand_tm = broadcast_shape(tm_, expand_rm.shape)
            br_q[i] =  np.sum(expand_rm*expand_tm, axis=-1)
        else:
            v = br_v[i+1]
            v_before_trans = expand_rm + v  # expand_rm and v are same shape
            expand_tm = broadcast_shape(tm_, v_before_trans.shape)  # get the same shape as v_before_trans
            br_q[i] = np.sum(v_before_trans*expand_tm, axis=-1)  # only sum over last dim: state

        if side == 'max':
            mu_dot_q = np.einsum('...i, ...ij->...j', policy[i], br_q[i])
            br_v[i] = np.min(mu_dot_q, axis=-1)
        else:
            q_dot_nu = np.einsum('...ij, ...j->...i', br_q[i], policy[i])
            br_v[i] = np.max(q_dot_nu, axis=-1)         

    avg_init_br_v = -np.mean(br_v[0])  # average best response value of initial states; minus for making it positive
    return avg_init_br_v

def get_best_response_value(player):
    # wrong! this is the weighted average (by meta strategy) of exploitability for each policy in policy set
    # per_policy_exploits = []
    # for p in policy_set:
    #     per_policy_exploits.append(best_response_value(trans_matrices, reward_matrices, p, num_actions_per_player, player['side']))
    # per_policy_exploits = np.array(per_policy_exploits)
    # print(per_policy_exploits)
    # exploitability = per_policy_exploits @ meta_strategy  # average over policy set weighted by meta strategy

    # should still get the posterior policy as the mixture policy to exploit!
    prior_mixture_policy = get_prior_policy(player['policy_set'], player['meta_strategy'])
    exploitability = best_response_value(trans_matrices, reward_matrices, prior_mixture_policy, num_actions_per_player, player['side'])

    return exploitability

def sample_policy(policy_set, dist):
    policy_id, _ = sample_from_categorical(dist)
    policy = policy_set[policy_id]   
    return policy 

# test_policy = create_expand_policy() 
# get_best_response(test_policy)

def xfp(env, save_path, solve_episodes = 1000):

    ini_max_policy = create_expand_policy()
    ini_min_policy = create_expand_policy()
    max_player = {
        'side': 'max',
        'policy_set': [ini_max_policy],
        'meta_strategy': np.array([1.])
    }
    min_player = {
        'side': 'min',
        'policy_set': [ini_min_policy],
        'meta_strategy': np.array([1.])
    }

    max_side_q_table = create_expand_Q()
    min_side_q_table = create_expand_Q()
 
    print('policy shape: ')
    for p in ini_max_policy:
        print(p.shape)
    print('Q table shape: ')
    for q in max_side_q_table:
        print(q.shape)

    exploitability_records = []

    for i in range(solve_episodes):
        s = env.reset()
        done = False
        max_player_observed_sequence = []
        min_player_observed_sequence = []
        max_player_conditional_sequence = []
        min_player_conditional_sequence = []
        max_player_action_prob_sequence = [[] for _ in max_player['policy_set']]
        min_player_action_prob_sequence = [[] for _ in min_player['policy_set']]
        shared_sequence_before_actions = []
        step = 0

        # sample policy from meta strategy for the current episode
        max_policy = sample_policy(max_player['policy_set'], max_player['meta_strategy'])
        min_policy = sample_policy(min_player['policy_set'], min_player['meta_strategy'])

        while not np.any(done):    
            # get observed sequence
            max_player_observed_sequence.extend([unified_state(s[0])])
            min_player_observed_sequence.extend([unified_state(s[1])])
            shared_sequence_before_actions = copy.deepcopy(max_player_observed_sequence)

            max_policy_to_choose = max_policy[step][tuple(max_player_observed_sequence)]  # a=np.ones([1,2]), b=(0,0), a[b] -> 1.
            min_policy_to_choose = min_policy[step][tuple(min_player_observed_sequence)]

            # choose action
            max_action, max_action_prob = sample_from_categorical(max_policy_to_choose)
            min_action, min_action_prob = sample_from_categorical(min_policy_to_choose)

            # roullout likelihood info for mixture policy
            if i % 2 == 0:  # update min player side
                for p_id, p in enumerate(max_player['policy_set']):  # get trajectory probabilities for each policy in policy set
                    max_p = p[step][tuple(max_player_observed_sequence)]
                    # _, max_a_prob = sample_from_categorical(max_p) # this is wrong
                    max_a_prob = max_p[max_action]  # get the probability of real action (rollout) under each policy in policy set
                    if step == 0:
                        max_player_action_prob_sequence[p_id].append(max_a_prob)
                    else:
                        max_player_action_prob_sequence[p_id].append(max_player_action_prob_sequence[p_id][-1]*max_a_prob)  # [p1, p1p2, p1p2p3, ...]
                max_player_conditional_sequence.append(copy.deepcopy(max_player_observed_sequence))
            else:
                for p_id, p in enumerate(min_player['policy_set']):
                    min_p = p[step][tuple(min_player_observed_sequence)]
                    # _, min_a_prob = sample_from_categorical(min_p)  # this is wrong
                    min_a_prob = min_p[min_action]  # get the probability of real action (rollout) under each policy in policy set
                    if step == 0:
                        min_player_action_prob_sequence[p_id].append(min_a_prob)
                    else:
                        min_player_action_prob_sequence[p_id].append(min_player_action_prob_sequence[p_id][-1]*min_a_prob)  # [p1, p1p2, p1p2p3, ...]
                min_player_conditional_sequence.append(copy.deepcopy(min_player_observed_sequence))

            action = [max_action, min_action]
            max_player_observed_sequence.extend(action)
            min_player_observed_sequence.extend(action)

            s_, r, done, _  = env.step(action)  
            s = s_

            step += 1
        
        # add new policy (best response policy for xfp) to policy set
        if i % 2 == 0:  # update min player side
            new_policy = get_best_response_policy(max_player, np.array(max_player_action_prob_sequence), max_player_conditional_sequence)  # get best response against the max player, max_player_action_prob_sequence: [#policies, H]
            min_player['policy_set'].append(new_policy) # add new policy to policy set to form mixture
            num_policies = len(min_player['policy_set'])
            min_player['meta_strategy'] = 1./num_policies*np.ones(num_policies)
        else: 
            new_policy = get_best_response_policy(min_player, np.array(min_player_action_prob_sequence), min_player_conditional_sequence) # get best response against the min player
            max_player['policy_set'].append(new_policy) # add new policy to policy set to form mixture
            num_policies = len(max_player['policy_set'])
            max_player['meta_strategy'] = 1./num_policies*np.ones(num_policies)

        if i % 10 == 0:
            exploitability = get_best_response_value(max_player)  # best response of the max player
            print(f'itr: {i}, exploitability: {exploitability}', )
            exploitability_records.append(exploitability)
            np.save(save_path, exploitability_records)

save_path = 'xfp_exp_stochastic.npy'
xfp(env, save_path, solve_episodes=10000)
# Out:
# policy shape:
# (3, 3)
# (3, 3, 3, 3, 3)
# (3, 3, 3, 3, 3, 3, 3, 3)
# Q table shape:
# (3, 3, 3)
# (3, 3, 3, 3, 3, 3)
# (3, 3, 3, 3, 3, 3, 3, 3, 3)
# itr: 0, exploitability: 0.7608750685387422
# itr: 10, exploitability: 0.5700058307610066
# itr: 20, exploitability: 0.4716761743838045
# itr: 30, exploitability: 0.3959845107783982
# itr: 40, exploitability: 0.3787387592695577
# itr: 50, exploitability: 0.39142434849146834
# itr: 60, exploitability: 0.3707183277383305
# itr: 70, exploitability: 0.3529372267209144
# itr: 80, exploitability: 0.3635982371725735
# itr: 90, exploitability: 0.3601669666472234
# itr: 100, exploitability: 0.347773374030596
# itr: 110, exploitability: 0.33959571816232853
# itr: 120, exploitability: 0.3373938098478571
# itr: 130, exploitability: 0.33720973783154856
# itr: 140, exploitability: 0.3423473567250392
# itr: 150, exploitability: 0.3541876682097649
# itr: 160, exploitability: 0.3489076889852682
# itr: 170, exploitability: 0.3380843506321895
# itr: 180, exploitability: 0.33165812088035646
# itr: 190, exploitability: 0.3250646347831734
# itr: 200, exploitability: 0.32688161962916495
# itr: 210, exploitability: 0.3329758520403288
# itr: 220, exploitability: 0.33408706606544847
# itr: 230, exploitability: 0.34359477505520925
# itr: 240, exploitability: 0.33978897095670924
# itr: 250, exploitability: 0.33485357987322056
# itr: 260, exploitability: 0.33493037600306463
# itr: 270, exploitability: 0.3295573197892238
# itr: 280, exploitability: 0.33153899900586054
# itr: 290, exploitability: 0.3301003711173616
# itr: 300, exploitability: 0.3318903611206217
# itr: 310, exploitability: 0.3381715059803523
# itr: 320, exploitability: 0.34020853287199654
# itr: 330, exploitability: 0.33800701814309364
# itr: 340, exploitability: 0.33416771559405906
# itr: 350, exploitability: 0.3320335833547714
# itr: 360, exploitability: 0.32972647812636496
# itr: 370, exploitability: 0.3264168122714352
# itr: 380, exploitability: 0.32723396106743985
# itr: 390, exploitability: 0.3305812513703043
# itr: 400, exploitability: 0.3324970198180553
# itr: 410, exploitability: 0.3313673682811734
# itr: 420, exploitability: 0.33224867915783196
# itr: 430, exploitability: 0.33375469706201727
# itr: 440, exploitability: 0.3300506247044681
# itr: 450, exploitability: 0.32849586435698996
# itr: 460, exploitability: 0.3261935548322982
# itr: 470, exploitability: 0.3277049199731675
# itr: 480, exploitability: 0.3246951845110533
# itr: 490, exploitability: 0.3221195541714246
# itr: 500, exploitability: 0.3217637002971186
# itr: 510, exploitability: 0.3232185060218706
# itr: 520, exploitability: 0.3237935013379138
# itr: 530, exploitability: 0.3240708789747899
# itr: 540, exploitability: 0.32448360626993905
# itr: 550, exploitability: 0.3241860438782499
# itr: 560, exploitability: 0.32571266419376527
# itr: 570, exploitability: 0.3265231618732241
# itr: 580, exploitability: 0.3285451360079921
# itr: 590, exploitability: 0.3277941639814316
# itr: 600, exploitability: 0.32692012118967734
# itr: 610, exploitability: 0.32486393105025696
# itr: 620, exploitability: 0.3231473724195433
# itr: 630, exploitability: 0.3187999607883418
# itr: 640, exploitability: 0.31798637335787855
# itr: 650, exploitability: 0.31703217582729304
# itr: 660, exploitability: 0.3166608407060904
# itr: 670, exploitability: 0.316205132480358
# itr: 680, exploitability: 0.31707347732350977
# itr: 690, exploitability: 0.31991615272027657
# itr: 700, exploitability: 0.3218800397795099
# itr: 710, exploitability: 0.32276352974197525
# itr: 720, exploitability: 0.3220084527098378
# itr: 730, exploitability: 0.32179715662984243
# itr: 740, exploitability: 0.32227198723977807
# itr: 750, exploitability: 0.3201146754054239
# itr: 760, exploitability: 0.3187171799268838
# itr: 770, exploitability: 0.31557137997079276
# itr: 780, exploitability: 0.31551834800909073
# itr: 790, exploitability: 0.3150892879974493
# itr: 800, exploitability: 0.3144476418323395
# itr: 810, exploitability: 0.31627324939753576
# itr: 820, exploitability: 0.31748415748013475
# itr: 830, exploitability: 0.31727973786677255
# itr: 840, exploitability: 0.317485400557419
# itr: 850, exploitability: 0.3156617657448295
# itr: 860, exploitability: 0.3152886155352696
# itr: 870, exploitability: 0.31387104489659534
# itr: 880, exploitability: 0.3165710380292976
# itr: 890, exploitability: 0.3168238806938946
# itr: 900, exploitability: 0.31831797320046984
# itr: 910, exploitability: 0.3203231437400686
# itr: 920, exploitability: 0.31871045683897736
# itr: 930, exploitability: 0.31951261661889535
# itr: 940, exploitability: 0.32068441946575776
# itr: 950, exploitability: 0.3215382751400862
# itr: 960, exploitability: 0.32185249875014427
# itr: 970, exploitability: 0.321244283644845
# itr: 980, exploitability: 0.3209907673373234
# itr: 990, exploitability: 0.32057089347309553
# itr: 1000, exploitability: 0.319536574412938
# itr: 1010, exploitability: 0.32028486497097325
# itr: 1020, exploitability: 0.3182084482825591
# itr: 1030, exploitability: 0.3166616539962394
# itr: 1040, exploitability: 0.3162686475855487
# itr: 1050, exploitability: 0.3168571448598347
# itr: 1060, exploitability: 0.3162852666060178
# itr: 1070, exploitability: 0.3158326888066854
# itr: 1080, exploitability: 0.31454812598485504
# itr: 1090, exploitability: 0.31478693723398277
# itr: 1100, exploitability: 0.31455525341748647
# itr: 1110, exploitability: 0.31449112720901673
# itr: 1120, exploitability: 0.31514175002962236
# itr: 1130, exploitability: 0.3167927915698017
# itr: 1140, exploitability: 0.3179120619911381
# itr: 1150, exploitability: 0.31816236117633895
# itr: 1160, exploitability: 0.3181942422065825
# itr: 1170, exploitability: 0.31802165722867154
# itr: 1180, exploitability: 0.31831599108227665
# itr: 1190, exploitability: 0.3178983789859045
# itr: 1200, exploitability: 0.3189270226648836
# itr: 1210, exploitability: 0.3210523834156817
# itr: 1220, exploitability: 0.32189581506946924
# itr: 1230, exploitability: 0.321066843044392
# itr: 1240, exploitability: 0.319571754365832
# itr: 1250, exploitability: 0.3192543212129756
# itr: 1260, exploitability: 0.3191991162392689
# itr: 1270, exploitability: 0.3185713233126652
# itr: 1280, exploitability: 0.3186202602238083
# itr: 1290, exploitability: 0.31848597199129
# itr: 1300, exploitability: 0.3171580493453641
# itr: 1310, exploitability: 0.31582557843974307
# itr: 1320, exploitability: 0.3151639860204912
# itr: 1330, exploitability: 0.313979020380783
# itr: 1340, exploitability: 0.31517719607784056
# itr: 1350, exploitability: 0.316814740655394
# itr: 1360, exploitability: 0.3166755435095894
# itr: 1370, exploitability: 0.31809482644047615
# itr: 1380, exploitability: 0.31903734283614377
# itr: 1390, exploitability: 0.3196516200464936
# itr: 1400, exploitability: 0.31910987532636104
# itr: 1410, exploitability: 0.3188931501188561
# itr: 1420, exploitability: 0.3191294054197536
# itr: 1430, exploitability: 0.3188884860500148
# itr: 1440, exploitability: 0.3188549406788375
# itr: 1450, exploitability: 0.3193276246200595
# itr: 1460, exploitability: 0.3207220070625753
# itr: 1470, exploitability: 0.3219635437871576
# itr: 1480, exploitability: 0.32198177108076076
# itr: 1490, exploitability: 0.3207551285023356
# itr: 1500, exploitability: 0.32119675655098284
# itr: 1510, exploitability: 0.32132329472999316
# itr: 1520, exploitability: 0.3211444948643008
# itr: 1530, exploitability: 0.3210886863100149
# itr: 1540, exploitability: 0.3208039652186405
# itr: 1550, exploitability: 0.3196015429952004
# itr: 1560, exploitability: 0.3188187139174075
# itr: 1570, exploitability: 0.31890301575260455
# itr: 1580, exploitability: 0.31910319692550376
# itr: 1590, exploitability: 0.3187620121210826
# itr: 1600, exploitability: 0.31787793043865686
# itr: 1610, exploitability: 0.3174351228040492
# itr: 1620, exploitability: 0.3173574704811751
# itr: 1630, exploitability: 0.3166802801161209
# itr: 1640, exploitability: 0.3163402665719867
# itr: 1650, exploitability: 0.31694124585398
# itr: 1660, exploitability: 0.31657950381794153
# itr: 1670, exploitability: 0.3163862065356512
# itr: 1680, exploitability: 0.31585542324922616
# itr: 1690, exploitability: 0.3151383188149129
# itr: 1700, exploitability: 0.3146267658674471
# itr: 1710, exploitability: 0.3137297615776799
# itr: 1720, exploitability: 0.3134268106747819
# itr: 1730, exploitability: 0.31304072390801846
# itr: 1740, exploitability: 0.31362762903485125
# itr: 1750, exploitability: 0.3145588720303155
# itr: 1760, exploitability: 0.31500784205028626
# itr: 1770, exploitability: 0.31529900772615865
# itr: 1780, exploitability: 0.31516717899863556
# itr: 1790, exploitability: 0.3148067564482601
# itr: 1800, exploitability: 0.3151430943079982
# itr: 1810, exploitability: 0.3155659414115252
# itr: 1820, exploitability: 0.3155863094711914
# itr: 1830, exploitability: 0.3153245541719489
# itr: 1840, exploitability: 0.31637469590384165
# itr: 1850, exploitability: 0.3162072730738262
# itr: 1860, exploitability: 0.31745540031280833
# itr: 1870, exploitability: 0.31735158434788874
# itr: 1880, exploitability: 0.31747167992957054
# itr: 1890, exploitability: 0.3175096078131652
# itr: 1900, exploitability: 0.3173860659224337
# itr: 1910, exploitability: 0.31718838449385584
# itr: 1920, exploitability: 0.31687849872435203
# itr: 1930, exploitability: 0.3166303162505532
# itr: 1940, exploitability: 0.3159867432714967
# itr: 1950, exploitability: 0.315576433114317
# itr: 1960, exploitability: 0.3147991811019984
# itr: 1970, exploitability: 0.31449088740044934
# itr: 1980, exploitability: 0.31343441924268456
# itr: 1990, exploitability: 0.3132233669705613
# itr: 2000, exploitability: 0.31327504344416895
# itr: 2010, exploitability: 0.31331181874252473
# itr: 2020, exploitability: 0.3135165581328192
# itr: 2030, exploitability: 0.31357196979060115
# itr: 2040, exploitability: 0.31344468530064357
# itr: 2050, exploitability: 0.3142136893889757
# itr: 2060, exploitability: 0.31435572259022954
# itr: 2070, exploitability: 0.31448495724010406
# itr: 2080, exploitability: 0.31474623030455395
# itr: 2090, exploitability: 0.315509435255571
# itr: 2100, exploitability: 0.3153722810520424
# itr: 2110, exploitability: 0.3153165950971403
# itr: 2120, exploitability: 0.31481382961061205
# itr: 2130, exploitability: 0.31475943115334654
# itr: 2140, exploitability: 0.315261950817248
# itr: 2150, exploitability: 0.31542032752441707
# itr: 2160, exploitability: 0.31546975883930256
# itr: 2170, exploitability: 0.31543314755824453
# itr: 2180, exploitability: 0.3150139110040169
# itr: 2190, exploitability: 0.3141502873117035
# itr: 2200, exploitability: 0.3136313676308196
# itr: 2210, exploitability: 0.31319881261956906
# itr: 2220, exploitability: 0.31283684969513553
# itr: 2230, exploitability: 0.31312666001274003
# itr: 2240, exploitability: 0.31371656781999346
# itr: 2250, exploitability: 0.31350244902431773
# itr: 2260, exploitability: 0.313763408459108
# itr: 2270, exploitability: 0.3144949283382364
# itr: 2280, exploitability: 0.3145726181289225
# itr: 2290, exploitability: 0.31483895527531985
# itr: 2300, exploitability: 0.31557157679482367
# itr: 2310, exploitability: 0.31577136132891254
# itr: 2320, exploitability: 0.3162005629901256
# itr: 2330, exploitability: 0.31651171419150087
# itr: 2340, exploitability: 0.31641852260612396
# itr: 2350, exploitability: 0.3161309821467935
# itr: 2360, exploitability: 0.3148647192086474
# itr: 2370, exploitability: 0.3142013465439834
# itr: 2380, exploitability: 0.31390184012437555
# itr: 2390, exploitability: 0.3142544183202585
# itr: 2400, exploitability: 0.3143742634185782
# itr: 2410, exploitability: 0.31388837001407993
# itr: 2420, exploitability: 0.31341522240486425
# itr: 2430, exploitability: 0.31307687801370415
# itr: 2440, exploitability: 0.313268636980968
# itr: 2450, exploitability: 0.3131529203140319
# itr: 2460, exploitability: 0.3130853068006519
# itr: 2470, exploitability: 0.31364169155616395
# itr: 2480, exploitability: 0.3141662712527818
# itr: 2490, exploitability: 0.31379745347142474
# itr: 2500, exploitability: 0.3141533581105678
# itr: 2510, exploitability: 0.31461716007197577
# itr: 2520, exploitability: 0.3142674498528199
# itr: 2530, exploitability: 0.31425763178335303
# itr: 2540, exploitability: 0.31407127555523223
# itr: 2550, exploitability: 0.3146038407287844
# itr: 2560, exploitability: 0.31480382821975017
# itr: 2570, exploitability: 0.31455198535881196
# itr: 2580, exploitability: 0.3142320625593205
# itr: 2590, exploitability: 0.3134907888706659
# itr: 2600, exploitability: 0.31375411527548935
# itr: 2610, exploitability: 0.3139483670558518
# itr: 2620, exploitability: 0.314017452524275
# itr: 2630, exploitability: 0.31352299188668814
# itr: 2640, exploitability: 0.31366333824715675
# itr: 2650, exploitability: 0.31331575112677096
# itr: 2660, exploitability: 0.31361925561220444
# itr: 2670, exploitability: 0.31379354974566137
# itr: 2680, exploitability: 0.31372879853378705
# itr: 2690, exploitability: 0.31371803988549624
# itr: 2700, exploitability: 0.3135845423358707
# itr: 2710, exploitability: 0.31325016155143753
# itr: 2720, exploitability: 0.3137017705882535
# itr: 2730, exploitability: 0.31392219567568347
# itr: 2740, exploitability: 0.31410734135862156
# itr: 2750, exploitability: 0.31391210385974666
# itr: 2760, exploitability: 0.3130717744209881
# itr: 2770, exploitability: 0.31289049133402896
# itr: 2780, exploitability: 0.3133311902148294
# itr: 2790, exploitability: 0.31337417189189315
# itr: 2800, exploitability: 0.3136232138733906
# itr: 2810, exploitability: 0.31399912823589354
# itr: 2820, exploitability: 0.31385233194150336
# itr: 2830, exploitability: 0.31357987140432186
# itr: 2840, exploitability: 0.3125494439418514
# itr: 2850, exploitability: 0.312132131331928
# itr: 2860, exploitability: 0.31223722230533424
# itr: 2870, exploitability: 0.31220792860078933
# itr: 2880, exploitability: 0.3124774304772831
# itr: 2890, exploitability: 0.312970264003957
# itr: 2900, exploitability: 0.31327058857525847
# itr: 2910, exploitability: 0.3135292844800486
# itr: 2920, exploitability: 0.3136041734600268
# itr: 2930, exploitability: 0.3141437850966613
# itr: 2940, exploitability: 0.3148568399585034
# itr: 2950, exploitability: 0.3148978131109157
# itr: 2960, exploitability: 0.3145288785439542
# itr: 2970, exploitability: 0.31411494389523015
# itr: 2980, exploitability: 0.31407908752565966
# itr: 2990, exploitability: 0.313647606800604
# itr: 3000, exploitability: 0.31312875116357913
# itr: 3010, exploitability: 0.31253850878987643
# itr: 3020, exploitability: 0.3120163974271832
# itr: 3030, exploitability: 0.31203327158694827
# itr: 3040, exploitability: 0.31140261854812434
# itr: 3050, exploitability: 0.31167759515624793
# itr: 3060, exploitability: 0.3118631497549159
# itr: 3070, exploitability: 0.3120312323345026
# itr: 3080, exploitability: 0.3121084937375136
# itr: 3090, exploitability: 0.3121698017938533
# itr: 3100, exploitability: 0.31204932761642035
# itr: 3110, exploitability: 0.3123497866351023
# itr: 3120, exploitability: 0.3125077271429078
# itr: 3130, exploitability: 0.3128736340665939
# itr: 3140, exploitability: 0.3130830455198556
# itr: 3150, exploitability: 0.3134524001205822
# itr: 3160, exploitability: 0.3135945039708122
# itr: 3170, exploitability: 0.31349355628788095
# itr: 3180, exploitability: 0.31285699310678244
# itr: 3190, exploitability: 0.3126691912454957
# itr: 3200, exploitability: 0.3121899829734924
# itr: 3210, exploitability: 0.3117199555017804
# itr: 3220, exploitability: 0.31108009739812253
# itr: 3230, exploitability: 0.3108681149719336
# itr: 3240, exploitability: 0.3106319762949582
# itr: 3250, exploitability: 0.3107625180734818
# itr: 3260, exploitability: 0.3106236345197227
# itr: 3270, exploitability: 0.3104838982005545
# itr: 3280, exploitability: 0.3099649382261596
# itr: 3290, exploitability: 0.3096133634898507
# itr: 3300, exploitability: 0.3094142226885311
# itr: 3310, exploitability: 0.30928677609992344
# itr: 3320, exploitability: 0.3097041258883833
# itr: 3330, exploitability: 0.30961254242957836
# itr: 3340, exploitability: 0.3097319036844406
# itr: 3350, exploitability: 0.3101211364547064
# itr: 3360, exploitability: 0.31034294307066546
# itr: 3370, exploitability: 0.3104601920298185
# itr: 3380, exploitability: 0.3106065357544254
# itr: 3390, exploitability: 0.31090070569143163
# itr: 3400, exploitability: 0.3103472830725823
# itr: 3410, exploitability: 0.3096999551627783
# itr: 3420, exploitability: 0.3092574510304937
# itr: 3430, exploitability: 0.3089313871135888
# itr: 3440, exploitability: 0.30848556188985904
# itr: 3450, exploitability: 0.30830666944546337
# itr: 3460, exploitability: 0.3087427064170407
# itr: 3470, exploitability: 0.30942280509485404
# itr: 3480, exploitability: 0.3103311356634764
# itr: 3490, exploitability: 0.31076171990941837
# itr: 3500, exploitability: 0.31093900264615365
# itr: 3510, exploitability: 0.3108734102692499
# itr: 3520, exploitability: 0.31082194786831724
# itr: 3530, exploitability: 0.3106073371970161
# itr: 3540, exploitability: 0.311032281882937
# itr: 3550, exploitability: 0.3110015924986042
# itr: 3560, exploitability: 0.3107613590450809
# itr: 3570, exploitability: 0.31085634973584014
# itr: 3580, exploitability: 0.3103425756779917
# itr: 3590, exploitability: 0.309899268063572
# itr: 3600, exploitability: 0.3094249378586316
# itr: 3610, exploitability: 0.3096886456718822
# itr: 3620, exploitability: 0.30995477240981223
# itr: 3630, exploitability: 0.3098548862078715
# itr: 3640, exploitability: 0.30966447465834585
# itr: 3650, exploitability: 0.30959720262283513
# itr: 3660, exploitability: 0.3094567550374185
# itr: 3670, exploitability: 0.3092813900242694
# itr: 3680, exploitability: 0.3096897076395521
# itr: 3690, exploitability: 0.30987326960279854
# itr: 3700, exploitability: 0.3098561991632575
# itr: 3710, exploitability: 0.3097861921837698
# itr: 3720, exploitability: 0.30948958138244115
# itr: 3730, exploitability: 0.30904153965744874
# itr: 3740, exploitability: 0.3088352921357268
# itr: 3750, exploitability: 0.3087609227714607
# itr: 3760, exploitability: 0.30855238842690624
# itr: 3770, exploitability: 0.3087351934835726
# itr: 3780, exploitability: 0.3090020515647983
# itr: 3790, exploitability: 0.30905158108849784
# itr: 3800, exploitability: 0.3088536806247625
# itr: 3810, exploitability: 0.30852824849453114
# itr: 3820, exploitability: 0.30869997166284463
# itr: 3830, exploitability: 0.3085049714828871
# itr: 3840, exploitability: 0.30837393037295696
# itr: 3850, exploitability: 0.30897562207533363
# itr: 3860, exploitability: 0.30911049818952246
# itr: 3870, exploitability: 0.30943206481844493
# itr: 3880, exploitability: 0.3096101005408564
# itr: 3890, exploitability: 0.3096825422676827
# itr: 3900, exploitability: 0.30994390709000463
# itr: 3910, exploitability: 0.3095746922065517
# itr: 3920, exploitability: 0.3091878145037546
# itr: 3930, exploitability: 0.3091427084493888
# itr: 3940, exploitability: 0.30898504722591785
# itr: 3950, exploitability: 0.30907593337347444
# itr: 3960, exploitability: 0.30924355090086214
# itr: 3970, exploitability: 0.3093371809643162
# itr: 3980, exploitability: 0.3097262565742082
# itr: 3990, exploitability: 0.30993651154011426
# itr: 4000, exploitability: 0.30995068129703623
# itr: 4010, exploitability: 0.31039709913367025
# itr: 4020, exploitability: 0.3104872850020368
# itr: 4030, exploitability: 0.31037274291623557
# itr: 4040, exploitability: 0.3099611766712584
# itr: 4050, exploitability: 0.3095115018978774
# itr: 4060, exploitability: 0.3092690236546705
# itr: 4070, exploitability: 0.30910077821492676
# itr: 4080, exploitability: 0.3090997669298154
# itr: 4090, exploitability: 0.3094172150384723
# itr: 4100, exploitability: 0.30956331163741124
# itr: 4110, exploitability: 0.30954719451249013
# itr: 4120, exploitability: 0.30929874233626425
# itr: 4130, exploitability: 0.30898929917495604
# itr: 4140, exploitability: 0.3091540531895217
# itr: 4150, exploitability: 0.3095251495331034
# itr: 4160, exploitability: 0.3098749769258939
# itr: 4170, exploitability: 0.31025379409056325
# itr: 4180, exploitability: 0.3099633047072483
# itr: 4190, exploitability: 0.31009448490677927
# itr: 4200, exploitability: 0.31021983060829333
# itr: 4210, exploitability: 0.30995903943473496
# itr: 4220, exploitability: 0.3099294480260751
# itr: 4230, exploitability: 0.30960804698869554
# itr: 4240, exploitability: 0.30956761627155777
# itr: 4250, exploitability: 0.3095662488943615
# itr: 4260, exploitability: 0.30963757726185165
# itr: 4270, exploitability: 0.30969081063279263
# itr: 4280, exploitability: 0.3101762842665751
# itr: 4290, exploitability: 0.3101030051714489
# itr: 4300, exploitability: 0.31022779671975914
# itr: 4310, exploitability: 0.3107175921025483
# itr: 4320, exploitability: 0.3106800518520651
# itr: 4330, exploitability: 0.3107752038742842
# itr: 4340, exploitability: 0.31078177316679656
# itr: 4350, exploitability: 0.3107285857611906
# itr: 4360, exploitability: 0.3109328353742525
# itr: 4370, exploitability: 0.31096815219171337
# itr: 4380, exploitability: 0.3110743444410195
# itr: 4390, exploitability: 0.31139028959645965
# itr: 4400, exploitability: 0.31136127933739627
# itr: 4410, exploitability: 0.31136598570418045
# itr: 4420, exploitability: 0.31110193392403357
# itr: 4430, exploitability: 0.31085655009033636
# itr: 4440, exploitability: 0.31080087363077225
# itr: 4450, exploitability: 0.31066604634735934
# itr: 4460, exploitability: 0.31044595640465855
# itr: 4470, exploitability: 0.31022943060523894
# itr: 4480, exploitability: 0.31006320117352637
# itr: 4490, exploitability: 0.31030447369016695
# itr: 4500, exploitability: 0.3105398103934088
# itr: 4510, exploitability: 0.3105686448067911
# itr: 4520, exploitability: 0.31061663644662335
# itr: 4530, exploitability: 0.3108191276440982
# itr: 4540, exploitability: 0.31096383754390666
# itr: 4550, exploitability: 0.31091361788328387
# itr: 4560, exploitability: 0.31105173572139005
# itr: 4570, exploitability: 0.3109975955459339
# itr: 4580, exploitability: 0.3109689802006956
# itr: 4590, exploitability: 0.31123986661867115
# itr: 4600, exploitability: 0.31160698030748674
# itr: 4610, exploitability: 0.3116114742660894
# itr: 4620, exploitability: 0.3117663612393872
# itr: 4630, exploitability: 0.31138906184521775
# itr: 4640, exploitability: 0.3111173225596456
# itr: 4650, exploitability: 0.31101706468990364
# itr: 4660, exploitability: 0.31121528862136366
# itr: 4670, exploitability: 0.311012821729717
# itr: 4680, exploitability: 0.31087064826821886
# itr: 4690, exploitability: 0.31066513751126196
# itr: 4700, exploitability: 0.3107127454873813
# itr: 4710, exploitability: 0.31043767246114684
# itr: 4720, exploitability: 0.3100085587560392
# itr: 4730, exploitability: 0.3097743558530734
# itr: 4740, exploitability: 0.30956862106973837
# itr: 4750, exploitability: 0.30933174649856454
# itr: 4760, exploitability: 0.30925765207198974
# itr: 4770, exploitability: 0.30960461347109747
# itr: 4780, exploitability: 0.3095695314294752
# itr: 4790, exploitability: 0.30963320874443484
# itr: 4800, exploitability: 0.310007443286
# itr: 4810, exploitability: 0.3101207654997329
# itr: 4820, exploitability: 0.3101609264937688
# itr: 4830, exploitability: 0.3104152563351633
# itr: 4840, exploitability: 0.3105441592266216
# itr: 4850, exploitability: 0.31056777984801326
# itr: 4860, exploitability: 0.3105153838664372
# itr: 4870, exploitability: 0.31053182523458894
# itr: 4880, exploitability: 0.3106492687849947
# itr: 4890, exploitability: 0.3108964582615335
# itr: 4900, exploitability: 0.31101289239999536
# itr: 4910, exploitability: 0.3112781745080905
# itr: 4920, exploitability: 0.3115414652405564
# itr: 4930, exploitability: 0.311576117410342
# itr: 4940, exploitability: 0.3116189799331989
# itr: 4950, exploitability: 0.31157166432701794
# itr: 4960, exploitability: 0.3113065866603585
# itr: 4970, exploitability: 0.311428440160096
# itr: 4980, exploitability: 0.31141601742718994
# itr: 4990, exploitability: 0.31120391734170744
# itr: 5000, exploitability: 0.3109923462328618
# itr: 5010, exploitability: 0.31074316332004265
# itr: 5020, exploitability: 0.31065598876064265
# itr: 5030, exploitability: 0.310335103129121
# itr: 5040, exploitability: 0.3098260535529293
# itr: 5050, exploitability: 0.3094043347504704
# itr: 5060, exploitability: 0.30956100582358687
# itr: 5070, exploitability: 0.30966671634844806
# itr: 5080, exploitability: 0.30961340175401264
# itr: 5090, exploitability: 0.30945819760236015
# itr: 5100, exploitability: 0.3091667379759427
# itr: 5110, exploitability: 0.3090417468741591
# itr: 5120, exploitability: 0.30886409067765824
# itr: 5130, exploitability: 0.3083834756475811
# itr: 5140, exploitability: 0.3080496265961919
# itr: 5150, exploitability: 0.3082586871062063
# itr: 5160, exploitability: 0.30848107034432415
# itr: 5170, exploitability: 0.3085776746497557
# itr: 5180, exploitability: 0.30871185983539345
# itr: 5190, exploitability: 0.30870870365879455
# itr: 5200, exploitability: 0.308933431204293
# itr: 5210, exploitability: 0.30893163065046975
# itr: 5220, exploitability: 0.3090658216236951
# itr: 5230, exploitability: 0.30919282273308574
# itr: 5240, exploitability: 0.3094964368420391
# itr: 5250, exploitability: 0.30973997143409027
# itr: 5260, exploitability: 0.3100261607705994
# itr: 5270, exploitability: 0.3103467100587986
# itr: 5280, exploitability: 0.310330625658014
# itr: 5290, exploitability: 0.3102947403543985
# itr: 5300, exploitability: 0.31043145407658335
# itr: 5310, exploitability: 0.3107583099355852
# itr: 5320, exploitability: 0.31082923294940873
# itr: 5330, exploitability: 0.31106921051307335
# itr: 5340, exploitability: 0.3113356631596144
# itr: 5350, exploitability: 0.3112354383380267
# itr: 5360, exploitability: 0.31135689038477676
# itr: 5370, exploitability: 0.3109151553748802
# itr: 5380, exploitability: 0.31045795868376885
# itr: 5390, exploitability: 0.30995461949070885
# itr: 5400, exploitability: 0.3097939546019365
# itr: 5410, exploitability: 0.3095801444651584
# itr: 5420, exploitability: 0.3096303162347915
# itr: 5430, exploitability: 0.309666178759539
# itr: 5440, exploitability: 0.3095814923276318
# itr: 5450, exploitability: 0.30938929580069435
# itr: 5460, exploitability: 0.3093446549977447
# itr: 5470, exploitability: 0.30903516535057846
# itr: 5480, exploitability: 0.3088208323345541
# itr: 5490, exploitability: 0.3086446335084461
# itr: 5500, exploitability: 0.30848246582597943
# itr: 5510, exploitability: 0.3082677007624243
# itr: 5520, exploitability: 0.3081422157260177
# itr: 5530, exploitability: 0.3081686886612188
# itr: 5540, exploitability: 0.30856890731223136
# itr: 5550, exploitability: 0.30887386060144745
# itr: 5560, exploitability: 0.30930049333805787
# itr: 5570, exploitability: 0.3094885428919499
# itr: 5580, exploitability: 0.3096297309756694
# itr: 5590, exploitability: 0.3096972126602922
# itr: 5600, exploitability: 0.3097768999083176
# itr: 5610, exploitability: 0.31024607706743573
# itr: 5620, exploitability: 0.3104981411900138
# itr: 5630, exploitability: 0.31084960722315286
# itr: 5640, exploitability: 0.3109916833302103
# itr: 5650, exploitability: 0.31126128213389015
# itr: 5660, exploitability: 0.31132446406420533
# itr: 5670, exploitability: 0.31144061974590903
# itr: 5680, exploitability: 0.3115725240624242
# itr: 5690, exploitability: 0.3113007469207981
# itr: 5700, exploitability: 0.31105612790026627
# itr: 5710, exploitability: 0.31076607089081254
# itr: 5720, exploitability: 0.310542436143235
# itr: 5730, exploitability: 0.31023640437586225
# itr: 5740, exploitability: 0.3103212074691715
# itr: 5750, exploitability: 0.31038920098554795
# itr: 5760, exploitability: 0.3105847650622035
# itr: 5770, exploitability: 0.3104805735876643
# itr: 5780, exploitability: 0.31021526290956486
# itr: 5790, exploitability: 0.3100986727564821
# itr: 5800, exploitability: 0.3098665842046247
# itr: 5810, exploitability: 0.30961661766740284
# itr: 5820, exploitability: 0.30956207510719075
# itr: 5830, exploitability: 0.30954195223432673
# itr: 5840, exploitability: 0.30950276446115393
# itr: 5850, exploitability: 0.3094697092372273
# itr: 5860, exploitability: 0.3094559683683013
# itr: 5870, exploitability: 0.30923297003975436
# itr: 5880, exploitability: 0.3089534732977499
# itr: 5890, exploitability: 0.3089078963493152
# itr: 5900, exploitability: 0.3092323592627699
# itr: 5910, exploitability: 0.3094360395359708
# itr: 5920, exploitability: 0.3093198337582566
# itr: 5930, exploitability: 0.3092507420099843
# itr: 5940, exploitability: 0.3093734232105976
# itr: 5950, exploitability: 0.309382859048823
# itr: 5960, exploitability: 0.30945931825533574
# itr: 5970, exploitability: 0.30967724428704746
# itr: 5980, exploitability: 0.3096942052953508
# itr: 5990, exploitability: 0.30952778906288864
# itr: 6000, exploitability: 0.3097268551429921
# itr: 6010, exploitability: 0.30982036195251145
# itr: 6020, exploitability: 0.3100250841641578
# itr: 6030, exploitability: 0.31022877863089027
# itr: 6040, exploitability: 0.31046076815143936
# itr: 6050, exploitability: 0.31065990584616193
# itr: 6060, exploitability: 0.31090627538620513
# itr: 6070, exploitability: 0.3108437956062167
# itr: 6080, exploitability: 0.3111063284544619
# itr: 6090, exploitability: 0.31101640108300793
# itr: 6100, exploitability: 0.3108655156261513
# itr: 6110, exploitability: 0.31083947981540916
# itr: 6120, exploitability: 0.3106447340062289
# itr: 6130, exploitability: 0.3104791631913479
# itr: 6140, exploitability: 0.31032483710176784
# itr: 6150, exploitability: 0.31011063028403946
# itr: 6160, exploitability: 0.3099473902648207
# itr: 6170, exploitability: 0.30992220144895166
# itr: 6180, exploitability: 0.30970889614336494
# itr: 6190, exploitability: 0.30951465310980925
# itr: 6200, exploitability: 0.3092905287514864
# itr: 6210, exploitability: 0.3090221828195805
# itr: 6220, exploitability: 0.30894666155182193
# itr: 6230, exploitability: 0.3087865558023768
# itr: 6240, exploitability: 0.3086546683045891
# itr: 6250, exploitability: 0.3088232822113935
# itr: 6260, exploitability: 0.3091721745301476
# itr: 6270, exploitability: 0.30955234580771424
# itr: 6280, exploitability: 0.3096771278056472
# itr: 6290, exploitability: 0.3097818262612468
# itr: 6300, exploitability: 0.3098876706151837
# itr: 6310, exploitability: 0.3098170488628816
# itr: 6320, exploitability: 0.30993624808972303
# itr: 6330, exploitability: 0.31004610610277544
# itr: 6340, exploitability: 0.3100556246519952
# itr: 6350, exploitability: 0.31034293631524484
# itr: 6360, exploitability: 0.3103848178717602
# itr: 6370, exploitability: 0.3103049170464143
# itr: 6380, exploitability: 0.3104243500262254
# itr: 6390, exploitability: 0.31055124100047143
# itr: 6400, exploitability: 0.3108181178418421
# itr: 6410, exploitability: 0.3108010714594971
# itr: 6420, exploitability: 0.31080735143157473
# itr: 6430, exploitability: 0.3108370978254985
# itr: 6440, exploitability: 0.3109898542267357
# itr: 6450, exploitability: 0.31132917599011306
# itr: 6460, exploitability: 0.3117386175590821
# itr: 6470, exploitability: 0.3119132998297791
# itr: 6480, exploitability: 0.3120760903979667
# itr: 6490, exploitability: 0.3119387179019609
# itr: 6500, exploitability: 0.31198449221643115
# itr: 6510, exploitability: 0.31217482497289445
# itr: 6520, exploitability: 0.31210072338295364
# itr: 6530, exploitability: 0.31202892942210786
# itr: 6540, exploitability: 0.3120205990601589
# itr: 6550, exploitability: 0.3121671476497167
# itr: 6560, exploitability: 0.3121046340798425
# itr: 6570, exploitability: 0.3121013268430854
# itr: 6580, exploitability: 0.3122772018629965
# itr: 6590, exploitability: 0.3122954754752552
# itr: 6600, exploitability: 0.31225478473006246
# itr: 6610, exploitability: 0.31219563974307485
# itr: 6620, exploitability: 0.31195496906090364
# itr: 6630, exploitability: 0.31174784571826525
# itr: 6640, exploitability: 0.3114819129951016
# itr: 6650, exploitability: 0.31139490655995933
# itr: 6660, exploitability: 0.3113674304006189
# itr: 6670, exploitability: 0.311416592937552
# itr: 6680, exploitability: 0.31131239391565374
# itr: 6690, exploitability: 0.31112969307099014
# itr: 6700, exploitability: 0.3109105984702515
# itr: 6710, exploitability: 0.3108928923178131
# itr: 6720, exploitability: 0.31089591011730777
# itr: 6730, exploitability: 0.31107210765925564
# itr: 6740, exploitability: 0.31106715807406793
# itr: 6750, exploitability: 0.31110325884976986
# itr: 6760, exploitability: 0.310879655700643
# itr: 6770, exploitability: 0.31070257282232044
# itr: 6780, exploitability: 0.3104333056435649
# itr: 6790, exploitability: 0.310222922797031
# itr: 6800, exploitability: 0.3100608612585582
# itr: 6810, exploitability: 0.3099787303018133
# itr: 6820, exploitability: 0.3100853099866459
# itr: 6830, exploitability: 0.3100888131201717
# itr: 6840, exploitability: 0.31020055306819494
# itr: 6850, exploitability: 0.3102488077282682
# itr: 6860, exploitability: 0.31017832418245245
# itr: 6870, exploitability: 0.3101505992359256
# itr: 6880, exploitability: 0.3100018519856271
# itr: 6890, exploitability: 0.3098553831617678
# itr: 6900, exploitability: 0.30983967249568384
# itr: 6910, exploitability: 0.3099510228210606
# itr: 6920, exploitability: 0.3100176902426489
# itr: 6930, exploitability: 0.3099349007011986
# itr: 6940, exploitability: 0.3097011092124929
# itr: 6950, exploitability: 0.3095198468408325
# itr: 6960, exploitability: 0.3093763918762591
# itr: 6970, exploitability: 0.3094456061533423
# itr: 6980, exploitability: 0.3094565125675303
# itr: 6990, exploitability: 0.30953693028513957
# itr: 7000, exploitability: 0.3097732541860657
# itr: 7010, exploitability: 0.30999212343489085
# itr: 7020, exploitability: 0.31021408194245204
# itr: 7030, exploitability: 0.31018136108647154
# itr: 7040, exploitability: 0.3102870223950728
# itr: 7050, exploitability: 0.3103722600615465
# itr: 7060, exploitability: 0.3103545256636989
# itr: 7070, exploitability: 0.3103872194840229
# itr: 7080, exploitability: 0.3104003490891575
# itr: 7090, exploitability: 0.3105030733137887
# itr: 7100, exploitability: 0.3107841082164583
# itr: 7110, exploitability: 0.31106621335404616
# itr: 7120, exploitability: 0.3111116823748144
# itr: 7130, exploitability: 0.31113623647550004
# itr: 7140, exploitability: 0.31104188169643276
# itr: 7150, exploitability: 0.311105487470267
# itr: 7160, exploitability: 0.3110835023068442
# itr: 7170, exploitability: 0.310963765880431
# itr: 7180, exploitability: 0.31100184494025235
# itr: 7190, exploitability: 0.31106059993929014
# itr: 7200, exploitability: 0.31121526576412
# itr: 7210, exploitability: 0.31130891880007144
# itr: 7220, exploitability: 0.3113198315644839
# itr: 7230, exploitability: 0.3113801946397685
# itr: 7240, exploitability: 0.31142262710961127
# itr: 7250, exploitability: 0.311446138693854
# itr: 7260, exploitability: 0.3112785123800598
# itr: 7270, exploitability: 0.31103192477010067
# itr: 7280, exploitability: 0.3109279501270685
# itr: 7290, exploitability: 0.3110761787452995
# itr: 7300, exploitability: 0.3111967318385657
# itr: 7310, exploitability: 0.31135857114307536
# itr: 7320, exploitability: 0.3117840113237674
# itr: 7330, exploitability: 0.31174417294335105
# itr: 7340, exploitability: 0.3116397816467066
# itr: 7350, exploitability: 0.3113490653448272
# itr: 7360, exploitability: 0.3110674397189194
# itr: 7370, exploitability: 0.3107606992592635
# itr: 7380, exploitability: 0.3106057787078102
# itr: 7390, exploitability: 0.3104036273822402
# itr: 7400, exploitability: 0.3104868792846874
# itr: 7410, exploitability: 0.31041469890167045
# itr: 7420, exploitability: 0.3106100949464727
# itr: 7430, exploitability: 0.3106557293025607
# itr: 7440, exploitability: 0.3105886131318018
# itr: 7450, exploitability: 0.3105231256494443
# itr: 7460, exploitability: 0.3104728333012078
# itr: 7470, exploitability: 0.31024558710408184
# itr: 7480, exploitability: 0.30990392780236414
# itr: 7490, exploitability: 0.30981194414736407
# itr: 7500, exploitability: 0.3099232949148249
# itr: 7510, exploitability: 0.3098815515683954
# itr: 7520, exploitability: 0.309946648410429
# itr: 7530, exploitability: 0.30994729723838405
# itr: 7540, exploitability: 0.3100559890225602
# itr: 7550, exploitability: 0.31020466804150865
# itr: 7560, exploitability: 0.3103008350282281
# itr: 7570, exploitability: 0.31030655352009856
# itr: 7580, exploitability: 0.3103045640642374
# itr: 7590, exploitability: 0.31044366686126584
# itr: 7600, exploitability: 0.31066215983866063
# itr: 7610, exploitability: 0.31087907911769447
# itr: 7620, exploitability: 0.31097406829397195
# itr: 7630, exploitability: 0.3112095809527376
# itr: 7640, exploitability: 0.31137535407374345
# itr: 7650, exploitability: 0.3111589861074437
# itr: 7660, exploitability: 0.31117906317728217
# itr: 7670, exploitability: 0.31124852623745736
# itr: 7680, exploitability: 0.31126272036438457
# itr: 7690, exploitability: 0.3113481580758325
# itr: 7700, exploitability: 0.3113734827850418
# itr: 7710, exploitability: 0.31143400786984937
# itr: 7720, exploitability: 0.31161481717800105
# itr: 7730, exploitability: 0.31173120735061466
# itr: 7740, exploitability: 0.3118086838134309
# itr: 7750, exploitability: 0.31191020811745174
# itr: 7760, exploitability: 0.31195701056188957
# itr: 7770, exploitability: 0.3119359623910462
# itr: 7780, exploitability: 0.31198264759670014
# itr: 7790, exploitability: 0.3120609950805447
# itr: 7800, exploitability: 0.3120191438373503
# itr: 7810, exploitability: 0.3119980933547331
# itr: 7820, exploitability: 0.31210930861765246
# itr: 7830, exploitability: 0.312305975784424
# itr: 7840, exploitability: 0.3124821043868851
# itr: 7850, exploitability: 0.3124822425745399
# itr: 7860, exploitability: 0.31248623554428884
# itr: 7870, exploitability: 0.3123412265094157
# itr: 7880, exploitability: 0.3121824897055994
# itr: 7890, exploitability: 0.31227961527118736
# itr: 7900, exploitability: 0.31227880236169414
# itr: 7910, exploitability: 0.3123213730490269
# itr: 7920, exploitability: 0.3123510269429563
# itr: 7930, exploitability: 0.31234066475756717
# itr: 7940, exploitability: 0.3122679543356915
# itr: 7950, exploitability: 0.31221047820515435
# itr: 7960, exploitability: 0.3121296384806153
# itr: 7970, exploitability: 0.31204928409177296
# itr: 7980, exploitability: 0.3119631236005564
# itr: 7990, exploitability: 0.31191997563090396
# itr: 8000, exploitability: 0.3119214839885776
# itr: 8010, exploitability: 0.31189350842846
# itr: 8020, exploitability: 0.31176210463795156
# itr: 8030, exploitability: 0.3115757645272296
# itr: 8040, exploitability: 0.3114610754131029
# itr: 8050, exploitability: 0.31134563547193145
# itr: 8060, exploitability: 0.3115070024196131
# itr: 8070, exploitability: 0.3116488451883495
# itr: 8080, exploitability: 0.3115463154285977
# itr: 8090, exploitability: 0.3114467711638574
# itr: 8100, exploitability: 0.31138584397571517
# itr: 8110, exploitability: 0.3112228308802959
# itr: 8120, exploitability: 0.3111181267129713
# itr: 8130, exploitability: 0.31096841028306893
# itr: 8140, exploitability: 0.31092351027622717
# itr: 8150, exploitability: 0.3108901834843833
# itr: 8160, exploitability: 0.31073061185909084
# itr: 8170, exploitability: 0.3106584861964102
# itr: 8180, exploitability: 0.31060296459644815
# itr: 8190, exploitability: 0.3105827136669193
# itr: 8200, exploitability: 0.3106112952520063
# itr: 8210, exploitability: 0.31073248795393194
# itr: 8220, exploitability: 0.31085552272539957
# itr: 8230, exploitability: 0.31080196752169464
# itr: 8240, exploitability: 0.31068114332556845
# itr: 8250, exploitability: 0.310486753035937
# itr: 8260, exploitability: 0.3103136346313672
# itr: 8270, exploitability: 0.3100984161765876
# itr: 8280, exploitability: 0.3099741529173712
# itr: 8290, exploitability: 0.3097835019735396
# itr: 8300, exploitability: 0.3095735442225126
# itr: 8310, exploitability: 0.3096450121472463
# itr: 8320, exploitability: 0.3097908825364018
# itr: 8330, exploitability: 0.3097727886966018
# itr: 8340, exploitability: 0.30984282817488473
# itr: 8350, exploitability: 0.3099702126796891
# itr: 8360, exploitability: 0.31023413979652675
# itr: 8370, exploitability: 0.31038892489076453
# itr: 8380, exploitability: 0.31045561595618015
# itr: 8390, exploitability: 0.3104520228669734
# itr: 8400, exploitability: 0.3103970205102504
# itr: 8410, exploitability: 0.3105061843036071
# itr: 8420, exploitability: 0.3106852419634741
# itr: 8430, exploitability: 0.3107551764232437
# itr: 8440, exploitability: 0.31087068881947766
# itr: 8450, exploitability: 0.3109809499521839
# itr: 8460, exploitability: 0.31117309307857105
# itr: 8470, exploitability: 0.31138372456384505
# itr: 8480, exploitability: 0.3115435226557333
# itr: 8490, exploitability: 0.3115016354794815
# itr: 8500, exploitability: 0.31142126446635865
# itr: 8510, exploitability: 0.31142097908969485
# itr: 8520, exploitability: 0.31138568142285317
# itr: 8530, exploitability: 0.31120977501618435
# itr: 8540, exploitability: 0.31110207763851216
# itr: 8550, exploitability: 0.311123590612759
# itr: 8560, exploitability: 0.31102941496196435
# itr: 8570, exploitability: 0.310803450484095
# itr: 8580, exploitability: 0.3107562169787542
# itr: 8590, exploitability: 0.31064372366629384
# itr: 8600, exploitability: 0.3107735870104505
# itr: 8610, exploitability: 0.31079405080237993
# itr: 8620, exploitability: 0.31078123517066075
# itr: 8630, exploitability: 0.31061086641360247
# itr: 8640, exploitability: 0.31036820521468683
# itr: 8650, exploitability: 0.3103771349993142
# itr: 8660, exploitability: 0.3102757082032488
# itr: 8670, exploitability: 0.3101973403232359
# itr: 8680, exploitability: 0.3101897767631986
# itr: 8690, exploitability: 0.31006832738448037
# itr: 8700, exploitability: 0.3100672628220731
# itr: 8710, exploitability: 0.3100957412448368
# itr: 8720, exploitability: 0.3099890712135534
# itr: 8730, exploitability: 0.30986103669450743
# itr: 8740, exploitability: 0.3097445800813104
# itr: 8750, exploitability: 0.3095616237997326
# itr: 8760, exploitability: 0.30975815953128505
# itr: 8770, exploitability: 0.3100182849367455
# itr: 8780, exploitability: 0.31025752751492885
# itr: 8790, exploitability: 0.3102231056909827
# itr: 8800, exploitability: 0.31035370088496095
# itr: 8810, exploitability: 0.3105337639020131
# itr: 8820, exploitability: 0.3107099680862811
# itr: 8830, exploitability: 0.3108410269038305
# itr: 8840, exploitability: 0.31075099527332495
# itr: 8850, exploitability: 0.3107375565135914
# itr: 8860, exploitability: 0.31087175257729766
# itr: 8870, exploitability: 0.3108623991170081
# itr: 8880, exploitability: 0.3107028244974522
# itr: 8890, exploitability: 0.3107415248197401
# itr: 8900, exploitability: 0.3108211373519273
# itr: 8910, exploitability: 0.3108708373644303
# itr: 8920, exploitability: 0.3109437185302166
# itr: 8930, exploitability: 0.31099443874225385
# itr: 8940, exploitability: 0.31112006613515886
# itr: 8950, exploitability: 0.31139926307804194
# itr: 8960, exploitability: 0.3115990110932529
# itr: 8970, exploitability: 0.3118477765794138
# itr: 8980, exploitability: 0.3117888365648405
# itr: 8990, exploitability: 0.3118175948981162
# itr: 9000, exploitability: 0.31188526000525013
# itr: 9010, exploitability: 0.31198802316819924
# itr: 9020, exploitability: 0.3120811041121923
# itr: 9030, exploitability: 0.3121217125154946
# itr: 9040, exploitability: 0.312097264003087
# itr: 9050, exploitability: 0.312172074609611
# itr: 9060, exploitability: 0.3121369532701755
# itr: 9070, exploitability: 0.3119552789491003
# itr: 9080, exploitability: 0.31194487581212405
# itr: 9090, exploitability: 0.31167888875207383
# itr: 9100, exploitability: 0.31162564814663674
# itr: 9110, exploitability: 0.31170474710124213
# itr: 9120, exploitability: 0.31165978929859156
# itr: 9130, exploitability: 0.3115862499073141
# itr: 9140, exploitability: 0.3115926264822706
# itr: 9150, exploitability: 0.3115747250324408
# itr: 9160, exploitability: 0.3116825589552242
# itr: 9170, exploitability: 0.31168022143901813
# itr: 9180, exploitability: 0.3116031387574602
# itr: 9190, exploitability: 0.3114511120625671
# itr: 9200, exploitability: 0.31126893897699354
# itr: 9210, exploitability: 0.31106874667104906
# itr: 9220, exploitability: 0.3110984561029532
# itr: 9230, exploitability: 0.3108850837483615
# itr: 9240, exploitability: 0.31075080558546736
# itr: 9250, exploitability: 0.3105929023205298
# itr: 9260, exploitability: 0.31045084293907477
# itr: 9270, exploitability: 0.31023253034986836
# itr: 9280, exploitability: 0.3099691927334269
# itr: 9290, exploitability: 0.3097354292763543
# itr: 9300, exploitability: 0.3096107455157339
# itr: 9310, exploitability: 0.30958188296022343
# itr: 9320, exploitability: 0.3095179362555032
# itr: 9330, exploitability: 0.30943191660224395
# itr: 9340, exploitability: 0.30944239027695597
# itr: 9350, exploitability: 0.3093807903097226
# itr: 9360, exploitability: 0.3094289700623571
# itr: 9370, exploitability: 0.30947479571840225
# itr: 9380, exploitability: 0.3095029054894287
# itr: 9390, exploitability: 0.30934761475737255
# itr: 9400, exploitability: 0.3092533928622351
# itr: 9410, exploitability: 0.3092558893959504
# itr: 9420, exploitability: 0.3092398075869767
# itr: 9430, exploitability: 0.30932266338946507
# itr: 9440, exploitability: 0.3094807341419487
# itr: 9450, exploitability: 0.30936589812288556
# itr: 9460, exploitability: 0.30927243009395283
# itr: 9470, exploitability: 0.30933460202893537
# itr: 9480, exploitability: 0.30947701479805206
# itr: 9490, exploitability: 0.3095738275548048
# itr: 9500, exploitability: 0.3097062860035196
# itr: 9510, exploitability: 0.3097824245376276
# itr: 9520, exploitability: 0.3099774139512151
# itr: 9530, exploitability: 0.3101497248184904
# itr: 9540, exploitability: 0.31020286484908377
# itr: 9550, exploitability: 0.31027323410146795
# itr: 9560, exploitability: 0.31042381489195014
# itr: 9570, exploitability: 0.3105550679903616
# itr: 9580, exploitability: 0.3106359469298108
# itr: 9590, exploitability: 0.31069139628310544
# itr: 9600, exploitability: 0.31090591652535354
# itr: 9610, exploitability: 0.31103918117206464
# itr: 9620, exploitability: 0.31097070163042745
# itr: 9630, exploitability: 0.3108446038729182
# itr: 9640, exploitability: 0.31061536260144545
# itr: 9650, exploitability: 0.3105351990628718
# itr: 9660, exploitability: 0.3103873592141772
# itr: 9670, exploitability: 0.31021896000339594
# itr: 9680, exploitability: 0.3100585247873548
# itr: 9690, exploitability: 0.30997202436619564
# itr: 9700, exploitability: 0.3099150621174907
# itr: 9710, exploitability: 0.3098816052610023
# itr: 9720, exploitability: 0.3098066297390117
# itr: 9730, exploitability: 0.3096805115952825
# itr: 9740, exploitability: 0.30964615431526027
# itr: 9750, exploitability: 0.3096217508840419
# itr: 9760, exploitability: 0.3096115767237166
# itr: 9770, exploitability: 0.30961308544761784
# itr: 9780, exploitability: 0.3096126863331926
# itr: 9790, exploitability: 0.30967837268452103
# itr: 9800, exploitability: 0.30952600599061947
# itr: 9810, exploitability: 0.3094851808601315
# itr: 9820, exploitability: 0.30971350162673006
# itr: 9830, exploitability: 0.30992979965266365
# itr: 9840, exploitability: 0.3100122410794403
# itr: 9850, exploitability: 0.31008829772816426
# itr: 9860, exploitability: 0.31017838466324016
# itr: 9870, exploitability: 0.3102111810904847
# itr: 9880, exploitability: 0.3102075147764412
# itr: 9890, exploitability: 0.310331597940847
# itr: 9900, exploitability: 0.3103736655167163
# itr: 9910, exploitability: 0.3104781426956507
# itr: 9920, exploitability: 0.310561833813071
# itr: 9930, exploitability: 0.3105819039253164
# itr: 9940, exploitability: 0.3105904154454025
# itr: 9950, exploitability: 0.3105558371798364
# itr: 9960, exploitability: 0.310608664693438
# itr: 9970, exploitability: 0.3105440562715963
# itr: 9980, exploitability: 0.3105727086725116
# itr: 9990, exploitability: 0.3106620289002163

# %%
import matplotlib.pyplot as plt

exp_data = np.load(save_path)
plt.title('XFP')
plt.xlabel('iter(x10)')
plt.ylabel('exploitability')
plt.xscale('log')
plt.yscale('log')
plt.plot(exp_data+oracle_v_star)

# %%
a=np.ones([1,2])
b=np.ones(2)
a@b
# Out:
# array([2.])
