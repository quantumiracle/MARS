# %% [markdown]
# # Exploitation Comparison of Different Zero-sum Game Methods
# The figures show the learning curve of the exploiter after the model is trained with different type of methods. The exploiter is set as the second player for all envs and methods.

# %%
import json

def load_data(file_name):
    file_dir = folder+files[0]
    file_dir = folder+file_name
    print(file_dir)
    
    data = json.load( open(file_dir+"/process.json"))
    print(data.keys())
    return data

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['savefig.facecolor']='white'
# plt.style.use('seaborn-whitegrid')
plt.style.use('default')
import matplotlib.cm as cm


def plot(data, method, color, agent_to_plot, smooth_radius=200, range=100000):
    def smooth(y, radius=200, mode='two_sided'):
        if len(y) < 2*radius+1:
            return np.ones_like(y) * y.mean()
        elif mode == 'two_sided':
            convkernel = np.ones(2 * radius+1)
            return np.convolve(y, convkernel, mode='same') / \
                   np.convolve(np.ones_like(y), convkernel, mode='same')
        elif mode == 'causal':
            convkernel = np.ones(radius)
            out = np.convolve(y, convkernel,mode='full') / \
                  np.convolve(np.ones_like(y), convkernel, mode='full')
            return out[:-radius+1]

    k = method
    v = data[agent_to_plot]
    plt.plot(v[:range], color=color, alpha=0.2)
    plt.plot(smooth(v[:range], radius=smooth_radius), color=color, label=k)

    
img_path = 'generated_img/'

# %%
env = 'boxing'
folder = '../data/log/20220112_0004_exploit/'
files = ! ls $folder
print(files)
colors = cm.rainbow(np.linspace(0, 1, 7))
# colors = ['r', 'b', 'c', 'orange', 'g', 'grey']
agent_to_plot = 'second_0'  # 'first_0' or 'second_0'
env_files =[f for f in files if env in f]
print(env_files)

for f, c in zip(env_files, colors):
    data = load_data(f)
    method = f.split('v1_')[-1]
    plot(data['episode_reward'], method, c, agent_to_plot, smooth_radius=200)

plt.legend()
plt.grid()
plt.title(f'Exploitation Test-{env}')
plt.xlabel('Episode')
plt.ylabel('Exploiter Reward')
# savepath=f'generated_img/compare_exploitation_{env}.pdf'
# plt.savefig(savepath, bbox_inches='tight',)
# Out:
# ['pettingzoo_boxing_v1_fictitious_selfplay2', 'pettingzoo_boxing_v1_nash_dqn', 'pettingzoo_boxing_v1_nash_dqn_exploiter', 'pettingzoo_boxing_v1_nfsp', 'pettingzoo_boxing_v1_nxdo2', 'pettingzoo_boxing_v1_selfplay2', 'pettingzoo_pong_v2_fictitious_selfplay2', 'pettingzoo_pong_v2_nash_dqn', 'pettingzoo_pong_v2_nash_dqn_exploiter', 'pettingzoo_pong_v2_nfsp', 'pettingzoo_pong_v2_nxdo2', 'pettingzoo_pong_v2_selfplay2', 'pettingzoo_surround_v1_fictitious_selfplay2', 'pettingzoo_surround_v1_nash_dqn', 'pettingzoo_surround_v1_nash_dqn_exploiter', 'pettingzoo_surround_v1_nfsp', 'pettingzoo_surround_v1_selfplay2', 'pettingzoo_tennis_v2_fictitious_selfplay2', 'pettingzoo_tennis_v2_nash_dqn', 'pettingzoo_tennis_v2_nash_dqn_exploiter', 'pettingzoo_tennis_v2_nfsp', 'pettingzoo_tennis_v2_nxdo2', 'pettingzoo_tennis_v2_selfplay2']
# ['pettingzoo_boxing_v1_fictitious_selfplay2', 'pettingzoo_boxing_v1_nash_dqn', 'pettingzoo_boxing_v1_nash_dqn_exploiter', 'pettingzoo_boxing_v1_nfsp', 'pettingzoo_boxing_v1_nxdo2', 'pettingzoo_boxing_v1_selfplay2']
# ../data/log/20220112_0004_exploit/pettingzoo_boxing_v1_fictitious_selfplay2
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220112_0004_exploit/pettingzoo_boxing_v1_nash_dqn
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220112_0004_exploit/pettingzoo_boxing_v1_nash_dqn_exploiter
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220112_0004_exploit/pettingzoo_boxing_v1_nfsp
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220112_0004_exploit/pettingzoo_boxing_v1_nxdo2
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220112_0004_exploit/pettingzoo_boxing_v1_selfplay2
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# Text(0, 0.5, 'Exploiter Reward')

# %%
env = 'pong'
folder = '../data/log/20220112_0004_exploit/'
files = ! ls $folder
print(files)
colors = cm.rainbow(np.linspace(0, 1, 7))
# colors = ['r', 'b', 'c', 'orange', 'g', 'grey']
agent_to_plot = 'second_0'  # 'first_0' or 'second_0'
env_files =[f for f in files if env in f]
print(env_files)

for f, c in zip(env_files, colors):
    data = load_data(f)
    method = f.split('v1_')[-1]
    plot(data['episode_reward'], method, c, agent_to_plot, smooth_radius=200)

plt.legend()
plt.grid()
plt.title(f'Exploitation Test-{env}')
plt.xlabel('Episode')
plt.ylabel('Exploiter Reward')
# savepath=f'generated_img/compare_exploitation_{env}.pdf'
# plt.savefig(savepath, bbox_inches='tight',)
# Out:
# ['pettingzoo_boxing_v1_fictitious_selfplay2', 'pettingzoo_boxing_v1_nash_dqn', 'pettingzoo_boxing_v1_nash_dqn_exploiter', 'pettingzoo_boxing_v1_nfsp', 'pettingzoo_boxing_v1_nxdo2', 'pettingzoo_boxing_v1_selfplay2', 'pettingzoo_pong_v2_fictitious_selfplay2', 'pettingzoo_pong_v2_nash_dqn', 'pettingzoo_pong_v2_nash_dqn_exploiter', 'pettingzoo_pong_v2_nfsp', 'pettingzoo_pong_v2_nxdo2', 'pettingzoo_pong_v2_selfplay2', 'pettingzoo_surround_v1_fictitious_selfplay2', 'pettingzoo_surround_v1_nash_dqn', 'pettingzoo_surround_v1_nash_dqn_exploiter', 'pettingzoo_surround_v1_nfsp', 'pettingzoo_surround_v1_selfplay2', 'pettingzoo_tennis_v2_fictitious_selfplay2', 'pettingzoo_tennis_v2_nash_dqn', 'pettingzoo_tennis_v2_nash_dqn_exploiter', 'pettingzoo_tennis_v2_nfsp', 'pettingzoo_tennis_v2_nxdo2', 'pettingzoo_tennis_v2_selfplay2']
# ['pettingzoo_pong_v2_fictitious_selfplay2', 'pettingzoo_pong_v2_nash_dqn', 'pettingzoo_pong_v2_nash_dqn_exploiter', 'pettingzoo_pong_v2_nfsp', 'pettingzoo_pong_v2_nxdo2', 'pettingzoo_pong_v2_selfplay2']
# ../data/log/20220112_0004_exploit/pettingzoo_pong_v2_fictitious_selfplay2
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220112_0004_exploit/pettingzoo_pong_v2_nash_dqn
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220112_0004_exploit/pettingzoo_pong_v2_nash_dqn_exploiter
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220112_0004_exploit/pettingzoo_pong_v2_nfsp
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220112_0004_exploit/pettingzoo_pong_v2_nxdo2
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220112_0004_exploit/pettingzoo_pong_v2_selfplay2
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# Text(0, 0.5, 'Exploiter Reward')

# %%
env = 'tennis'
folder = '../data/log/20220112_0004_exploit/'
files = ! ls $folder
print(files)
colors = cm.rainbow(np.linspace(0, 1, 7))
# colors = ['r', 'b', 'c', 'orange', 'g', 'grey']
agent_to_plot = 'second_0'  # 'first_0' or 'second_0'
env_files =[f for f in files if env in f]
print(env_files)

for f, c in zip(env_files, colors):
    data = load_data(f)
    method = f.split('v1_')[-1]
    plot(data['episode_reward'], method, c, agent_to_plot, smooth_radius=200)

plt.legend()
plt.grid()
plt.title(f'Exploitation Test-{env}')
plt.xlabel('Episode')
plt.ylabel('Exploiter Reward')
# savepath=f'generated_img/compare_exploitation_{env}.pdf'
# plt.savefig(savepath, bbox_inches='tight',)
# Out:
# ['pettingzoo_boxing_v1_fictitious_selfplay2', 'pettingzoo_boxing_v1_nash_dqn', 'pettingzoo_boxing_v1_nash_dqn_exploiter', 'pettingzoo_boxing_v1_nfsp', 'pettingzoo_boxing_v1_nxdo2', 'pettingzoo_boxing_v1_selfplay2', 'pettingzoo_pong_v2_fictitious_selfplay2', 'pettingzoo_pong_v2_nash_dqn', 'pettingzoo_pong_v2_nash_dqn_exploiter', 'pettingzoo_pong_v2_nfsp', 'pettingzoo_pong_v2_nxdo2', 'pettingzoo_pong_v2_selfplay2', 'pettingzoo_surround_v1_fictitious_selfplay2', 'pettingzoo_surround_v1_nash_dqn', 'pettingzoo_surround_v1_nash_dqn_exploiter', 'pettingzoo_surround_v1_nfsp', 'pettingzoo_surround_v1_selfplay2', 'pettingzoo_tennis_v2_fictitious_selfplay2', 'pettingzoo_tennis_v2_nash_dqn', 'pettingzoo_tennis_v2_nash_dqn_exploiter', 'pettingzoo_tennis_v2_nfsp', 'pettingzoo_tennis_v2_nxdo2', 'pettingzoo_tennis_v2_selfplay2']
# ['pettingzoo_tennis_v2_fictitious_selfplay2', 'pettingzoo_tennis_v2_nash_dqn', 'pettingzoo_tennis_v2_nash_dqn_exploiter', 'pettingzoo_tennis_v2_nfsp', 'pettingzoo_tennis_v2_nxdo2', 'pettingzoo_tennis_v2_selfplay2']
# ../data/log/20220112_0004_exploit/pettingzoo_tennis_v2_fictitious_selfplay2
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220112_0004_exploit/pettingzoo_tennis_v2_nash_dqn
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220112_0004_exploit/pettingzoo_tennis_v2_nash_dqn_exploiter
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220112_0004_exploit/pettingzoo_tennis_v2_nfsp
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220112_0004_exploit/pettingzoo_tennis_v2_nxdo2
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220112_0004_exploit/pettingzoo_tennis_v2_selfplay2
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# Text(0, 0.5, 'Exploiter Reward')

# %%
env = 'surround'
folder = '../data/log/20220112_0004_exploit/'
files = ! ls $folder
print(files)
colors = cm.rainbow(np.linspace(0, 1, 7))
# colors = ['r', 'b', 'c', 'orange', 'g', 'grey']
agent_to_plot = 'second_0'  # 'first_0' or 'second_0'
env_files =[f for f in files if env in f]
print(env_files)

for f, c in zip(env_files, colors):
    try:
        data = load_data(f)
        method = f.split('v1_')[-1]
        plot(data['episode_reward'], method, c, agent_to_plot, smooth_radius=200)
    except:
        pass

plt.legend()
plt.grid()
plt.title(f'Exploitation Test-{env}')
plt.xlabel('Episode')
plt.ylabel('Exploiter Reward')
# savepath=f'generated_img/compare_exploitation_{env}.pdf'
# plt.savefig(savepath, bbox_inches='tight',)
# Out:
# ['pettingzoo_boxing_v1_fictitious_selfplay2', 'pettingzoo_boxing_v1_nash_dqn', 'pettingzoo_boxing_v1_nash_dqn_exploiter', 'pettingzoo_boxing_v1_nfsp', 'pettingzoo_boxing_v1_nxdo2', 'pettingzoo_boxing_v1_selfplay2', 'pettingzoo_pong_v2_fictitious_selfplay2', 'pettingzoo_pong_v2_nash_dqn', 'pettingzoo_pong_v2_nash_dqn_exploiter', 'pettingzoo_pong_v2_nfsp', 'pettingzoo_pong_v2_nxdo2', 'pettingzoo_pong_v2_selfplay2', 'pettingzoo_surround_v1_fictitious_selfplay2', 'pettingzoo_surround_v1_nash_dqn', 'pettingzoo_surround_v1_nash_dqn_exploiter', 'pettingzoo_surround_v1_nfsp', 'pettingzoo_surround_v1_selfplay2', 'pettingzoo_tennis_v2_fictitious_selfplay2', 'pettingzoo_tennis_v2_nash_dqn', 'pettingzoo_tennis_v2_nash_dqn_exploiter', 'pettingzoo_tennis_v2_nfsp', 'pettingzoo_tennis_v2_nxdo2', 'pettingzoo_tennis_v2_selfplay2']
# ['pettingzoo_surround_v1_fictitious_selfplay2', 'pettingzoo_surround_v1_nash_dqn', 'pettingzoo_surround_v1_nash_dqn_exploiter', 'pettingzoo_surround_v1_nfsp', 'pettingzoo_surround_v1_selfplay2']
# ../data/log/20220112_0004_exploit/pettingzoo_surround_v1_fictitious_selfplay2
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220112_0004_exploit/pettingzoo_surround_v1_nash_dqn
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220112_0004_exploit/pettingzoo_surround_v1_nash_dqn_exploiter
# ../data/log/20220112_0004_exploit/pettingzoo_surround_v1_nfsp
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# ../data/log/20220112_0004_exploit/pettingzoo_surround_v1_selfplay2
# dict_keys(['episode_reward', 'loss', 'episode_length'])
# Text(0, 0.5, 'Exploiter Reward')

# %%
env = 'ice_hockey'
folder = '../data/log/20220112_0004_exploit/'
files = ! ls $folder
print(files)
colors = cm.rainbow(np.linspace(0, 1, 7))
# colors = ['r', 'b', 'c', 'orange', 'g', 'grey']
agent_to_plot = 'second_0'  # 'first_0' or 'second_0'
env_files =[f for f in files if env in f]
print(env_files)

for f, c in zip(env_files, colors):
    data = load_data(f)
    method = f.split('v1_')[-1]
    plot(data['episode_reward'], method, c, agent_to_plot, smooth_radius=200)

plt.legend()
plt.grid()
plt.title(f'Exploitation Test-{env}')
plt.xlabel('Episode')
plt.ylabel('Exploiter Reward')
# savepath=f'generated_img/compare_exploitation_{env}.pdf'
# plt.savefig(savepath, bbox_inches='tight',)
# Out:
# No handles with labels found to put in legend.
# ['pettingzoo_boxing_v1_fictitious_selfplay2', 'pettingzoo_boxing_v1_nash_dqn', 'pettingzoo_boxing_v1_nash_dqn_exploiter', 'pettingzoo_boxing_v1_nfsp', 'pettingzoo_boxing_v1_nxdo2', 'pettingzoo_boxing_v1_selfplay2', 'pettingzoo_pong_v2_fictitious_selfplay2', 'pettingzoo_pong_v2_nash_dqn', 'pettingzoo_pong_v2_nash_dqn_exploiter', 'pettingzoo_pong_v2_nfsp', 'pettingzoo_pong_v2_nxdo2', 'pettingzoo_pong_v2_selfplay2', 'pettingzoo_surround_v1_fictitious_selfplay2', 'pettingzoo_surround_v1_nash_dqn', 'pettingzoo_surround_v1_nash_dqn_exploiter', 'pettingzoo_surround_v1_nfsp', 'pettingzoo_surround_v1_selfplay2', 'pettingzoo_tennis_v2_fictitious_selfplay2', 'pettingzoo_tennis_v2_nash_dqn', 'pettingzoo_tennis_v2_nash_dqn_exploiter', 'pettingzoo_tennis_v2_nfsp', 'pettingzoo_tennis_v2_nxdo2', 'pettingzoo_tennis_v2_selfplay2']
# []
# Text(0, 0.5, 'Exploiter Reward')
